# %%
import pandas as pd
import numpy as np
from math import sin, cos, atan2, sqrt, radians
from ortools.constraint_solver import pywrapcp, routing_enums_pb2

# %%
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv(
    'data/Bezoeken per voertuig 01-01-2025 - 31-12-2025.Csv',
    sep=';',
    encoding='utf-16',
    skiprows=1
)
# Out:
# C:\Users\aniek.kasius\AppData\Local\Temp\ipykernel_10556\1523193955.py:1: DtypeWarning: Columns (0: Contact) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(

# %%
# Datum en tijd goed zetten
df["Date"] = pd.to_datetime(df["Date"], dayfirst=True, errors="coerce")

# Sorteren op echte ritvolgorde
df = df.sort_values(["Date", "SerialNumber", "StartRide"]).copy()

# %%
df
# Out:
#           SerialNumber       Date StartRide  Start   Stop Distance TravelTime  \
# 4156   1040 (VFT-36-H) 2025-01-01     13:57  13:57  13:59     0,00      00:00
# 4157   1040 (VFT-36-H) 2025-01-01     13:59  14:00  07:04     0,17      00:00
# 23890  1326 (VNT-05-X) 2025-01-01     10:52  10:54  06:48     0,56      00:01
# 34792  1515 (VVF-65-D) 2025-01-01     10:28  11:12  11:28    55,60      00:43
# 34793  1515 (VVF-65-D) 2025-01-01     11:28  12:08  12:14    52,00      00:39
# ...                ...        ...       ...    ...    ...      ...        ...
# 59128  1775 (V-11-GGL) 2025-12-31     09:17  09:28  10:18     5,81      00:10
# 59129  1775 (V-11-GGL) 2025-12-31     10:18  10:38  10:57     6,61      00:19
# 59130  1775 (V-11-GGL) 2025-12-31     10:57  11:28  11:46    22,78      00:30
# 59131  1775 (V-11-GGL) 2025-12-31     11:46  11:54  12:02     1,99      00:08
# 59132  1775 (V-11-GGL) 2025-12-31     12:02  12:10  12:21     5,18      00:08
#
#       Duration                        VisitingAddress  \
# 4156      0:01   Dokter Rietveldplein 22, Papendrecht
# 4157     17:04   Dokter Rietveldplein 22, Papendrecht
# 23890    19:54        Slobbengorsweg 100, Papendrecht
# 34792     0:15               Onyxdijk 167, Roosendaal
# 34793     0:05              Prickwaert 66, Sliedrecht
# ...        ...                                    ...
# 59128     0:50        Van Beethovenlaan 56, Rotterdam
# 59129     0:19  Dotterlei 143, Capelle Aan Den Ijssel
# 59130     0:17  Groen Van Prinstererweg 38, Dordrecht
# 59131     0:07               Minnaertweg 4, Dordrecht
# 59132     0:11       Kamerlingh Onnesweg 9, Dordrecht
#
#                      Description                DriverName          GroupName  \
# 4156                         NaN                       NaN  BBT Dordrecht/MHG
# 4157                         NaN                       NaN  BBT Dordrecht/MHG
# 23890                        NaN                       NaN  BBT Dordrecht/MHG
# 34792                        NaN  Cornelis van der Giessen  BBT Dordrecht/MHG
# 34793                        NaN  Cornelis van der Giessen  BBT Dordrecht/MHG
# ...                          ...                       ...                ...
# 59128                        NaN              Patrick Baas  BBT Dordrecht/MHG
# 59129                        NaN              Patrick Baas  BBT Dordrecht/MHG
# 59130                        NaN              Patrick Baas  BBT Dordrecht/MHG
# 59131                        NaN              Patrick Baas  BBT Dordrecht/MHG
# 59132  Medux Kamerlingh Onnesweg              Patrick Baas  BBT Dordrecht/MHG
#
#       Contact Remark                          To  ZipCode  \
# 4156      NaN    NaN     Dokter Rietveldplein 22  3353SJ
# 4157      NaN    NaN     Dokter Rietveldplein 22  3353SJ
# 23890     NaN    NaN          Slobbengorsweg 100  3351LH
# 34792     NaN    NaN                Onyxdijk 167  4706LL
# 34793     NaN    NaN               Prickwaert 66  3363BD
# ...       ...    ...                         ...      ...
# 59128     NaN    NaN        Van Beethovenlaan 56   3055JD
# 59129     NaN    NaN               Dotterlei 143  2906BC
# 59130     NaN    NaN  Groen Van Prinstererweg 38  3317SP
# 59131     NaN    NaN               Minnaertweg 4   3328HN
# 59132     NaN    NaN       Kamerlingh Onnesweg 9  3316 GK
#
#                          City  ProjectNumber Break TotalTime TotalTravelTime  \
# 4156              Papendrecht            NaN  0:00      0:02            0:00
# 4157              Papendrecht            NaN  0:00      0:03            0:01
# 23890             Papendrecht            NaN  0:00      0:01            0:01
# 34792              Roosendaal            NaN  0:00      0:59            0:43
# 34793              Sliedrecht            NaN  0:00      1:45            1:23
# ...                       ...            ...   ...       ...             ...
# 59128               Rotterdam            NaN  0:00      3:50            1:27
# 59129  Capelle Aan Den Ijssel            NaN  0:00      4:29            1:47
# 59130               Dordrecht            NaN  0:00      5:18            2:18
# 59131               Dordrecht            NaN  0:00      5:34            2:26
# 59132               Dordrecht            0.0  0:00      5:53            2:34
#
#       TotalDuration TotalTimeMinusBreak TotalDistance        Lat      Long
# 4156           0:01                0:00          0,00  51.823878  4.689373
# 4157           0:01                0:03          0,17  51.823918  4.689510
# 23890          0:00                0:01          0,56  51.823409  4.677820
# 34792          0:15                0:00         55,60  51.518796  4.492111
# 34793          0:21                0:00        107,60  51.827532  4.758798
# ...             ...                 ...           ...        ...       ...
# 59128          2:22                0:00         68,85  51.956123  4.512793
# 59129          2:42                0:00         75,46  51.932790  4.563842
# 59130          3:00                0:00         98,24  51.790982  4.665400
# 59131          3:07                0:00        100,23  51.783413  4.686293
# 59132          3:18                5:53        105,41  51.780550  4.639417
#
# [59133 rows x 26 columns]

# %%
# bekijken welke auto's elke dag naar het depot gaan
depot_naam = "Kamerlingh Onnesweg 9, Dordrecht"

# %%
# als de dataframe al in de juiste volgorde staat:
# per Date en SerialNumber de eerste en laatste rij pakken

eerste_stop = (
    df.groupby(["Date", "SerialNumber"], sort=False)
      .first()
      .reset_index()[["Date", "SerialNumber", "VisitingAddress"]]
      .rename(columns={"VisitingAddress": "eerste_stop"})
)

laatste_stop = (
    df.groupby(["Date", "SerialNumber"], sort=False)
      .last()
      .reset_index()[["Date", "SerialNumber", "VisitingAddress"]]
      .rename(columns={"VisitingAddress": "laatste_stop"})
)

# samenvoegen
start_eind_check = eerste_stop.merge(
    laatste_stop,
    on=["Date", "SerialNumber"],
    how="inner"
)

# alleen groepen die starten én eindigen bij depot
groepen_depot_start_eind = start_eind_check[
    (start_eind_check["eerste_stop"] == depot_naam) &
    (start_eind_check["laatste_stop"] == depot_naam)
][["Date", "SerialNumber"]]

# originele dataset filteren op die groepen
df01 = df.merge(
    groepen_depot_start_eind,
    on=["Date", "SerialNumber"],
    how="inner"
kamerlingh Onnesweg 9  3316 GK               Dordrecht
# ...     ...                         ...      ...                     ...
# 2741    NaN        Van Beethovenlaan 56   3055JD               Rotterdam
# 2742    NaN               Dotterlei 143  2906BC   Capelle Aan Den Ijssel
# 2743    NaN  Groen Van Prinstererweg 38  3317SP                Dordrecht
# 2744    NaN               Minnaertweg 4   3328HN               Dordrecht
# 2745    NaN       Kamerlingh Onnesweg 9  3316 GK               Dordrecht
#
#       ProjectNumber Break TotalTime TotalTravelTime TotalDuration  \
# 0               0.0  0:00      0:32            0:00          0:32
# 1               0.0  0:00      0:32            0:00          0:32
# 2               0.0  0:00      0:32            0:00          0:32
# 3               0.0  0:00      0:32            0:00          0:32
# 4               0.0  0:00      0:33            0:00          0:32
# ...             ...   ...       ...             ...           ...
# 2741            NaN  0:00      3:50            1:27          2:22
# 2742            NaN  0:00      4:29            1:47          2:42
# 2743            NaN  0:00      5:18            2:18          3:00
# 2744            NaN  0:00      5:34            2:26          3:07
# 2745            0.0  0:00      5:53            2:34          3:18
#
#      TotalTimeMinusBreak TotalDistance        Lat      Long
# 0                   0:00          0,00  51.780550  4.638887
# 1                   0:00          0,00  51.780622  4.638795
# 2                   0:00          0,00  51.780622  4.638792
# 3                   0:00          0,00  51.780622  4.638792
# 4                   0:00          0,00  51.780622  4.638792
# ...                  ...           ...        ...       ...
# 2741                0:00         68,85  51.956123  4.512793
# 2742                0:00         75,46  51.932790  4.563842
# 2743                0:00         98,24  51.790982  4.665400
# 2744                0:00        100,23  51.783413  4.686293
# 2745                5:53        105,41  51.780550  4.639417
#
# [2746 rows x 26 columns]

# %%
# meerdere latitutes voor zelfde adres dus nu de gemiddelde nemen van de coordinaten en dat gebruiken als coördinaat van dat adres
coords_per_adres = df01.groupby("VisitingAddress")[["Lat", "Long"]].mean().reset_index()

# %%
df01 = df01.drop(columns=["Lat", "Long"])

df01 = df01.merge(coords_per_adres, on="VisitingAddress", how="left")

# %%
df01.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2746 entries, 0 to 2745
# Data columns (total 26 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   SerialNumber         2746 non-null   str
#  1   Date                 2746 non-null   datetime64[us]
#  2   StartRide            2746 non-null   str
#  3   Start                2746 non-null   str
#  4   Stop                 2746 non-null   str
#  5   Distance             2746 non-null   str
#  6   TravelTime           2746 non-null   str
#  7   Duration             2746 non-null   str
#  8   VisitingAddress      2746 non-null   str
#  9   Description          776 non-null    str
#  10  DriverName           2568 non-null   str
#  11  GroupName            2746 non-null   str
#  12  Contact              0 non-null      object
#  13  Remark               0 non-null      str
#  14  To                   2744 non-null   str
#  15  ZipCode              2741 non-null   str
#  16  City                 2746 non-null   str
#  17  ProjectNumber        776 non-null    float64
#  18  Break                2746 non-null   str
#  19  TotalTime            2746 non-null   str
#  20  TotalTravelTime      2746 non-null   str
#  21  TotalDuration        2746 non-null   str
#  22  TotalTimeMinusBreak  2746 non-null   str
#  23  TotalDistance        2746 non-null   str
#  24  Lat                  2746 non-null   float64
#  25  Long                 2746 non-null   float64
# dtypes: datetime64[us](1), float64(3), object(1), str(21)
# memory usage: 557.9+ KB

# %%
# missende waarden zipcode toevoegen
df01[df01['ZipCode'].isna()]
# Out:
#          SerialNumber       Date StartRide  Start   Stop Distance TravelTime  \
# 360   1313 (VPS-11-J) 2025-02-18     07:26  07:26  08:09     0,00      00:00
# 546   1775 (V-11-GGL) 2025-03-06     11:19  11:20  11:36     0,17      00:01
# 726   1775 (V-11-GGL) 2025-03-26     11:04  11:05  12:21     0,18      00:00
# 1788  1705 (V-18-FXR) 2025-08-14     10:29  11:01  11:01    30,74      00:32
# 1814  1705 (V-18-FXR) 2025-08-15     10:20  10:58  11:07    30,84      00:38
#
#      Duration                         VisitingAddress Description  \
# 360      0:42                                     , ?         NaN
# 546      0:16  Amphia Ziekenhuis Molengracht 1, Breda         NaN
# 726      1:16  Amphia Ziekenhuis Molengracht 1, Breda         NaN
# 1788     0:00                                  De Val         NaN
# 1814     0:08                 Straalweg 10, Zierikzee         NaN
#
#                  DriverName          GroupName Contact Remark  \
# 360            Robin Kovács  BBT Dordrecht/MHG     NaN    NaN
# 546            Frido Wijnen  BBT Dordrecht/MHG     NaN    NaN
# 726   Geertjan van der Wulp  BBT Dordrecht/MHG     NaN    NaN
# 1788          Marcus Dekker  BBT Dordrecht/MHG     NaN    NaN
# 1814          Marcus Dekker  BBT Dordrecht/MHG     NaN    NaN
#
#                                    To ZipCode       City  ProjectNumber Break  \
# 360                               NaN     NaN          ?            NaN  0:00
# 546   Amphia Ziekenhuis Molengracht 1     NaN      Breda            NaN  0:00
# 726   Amphia Ziekenhuis Molengracht 1     NaN      Breda            NaN  0:00
# 1788                              NaN     NaN     De Val            NaN  0:00
# 1814                     Straalweg 10     NaN  Zierikzee            NaN  0:00
#
#      TotalTime TotalTravelTime TotalDuration TotalTimeMinusBreak  \
# 360       1:31            0:39          0:51                0:00
# 546       4:09            2:00          2:09                0:00
# 726       4:33            1:15          3:17                0:00
# 1788      4:15            2:19          1:56                0:00
# 1814      4:39            2:24          2:15                0:00
#
#      TotalDistance        Lat      Long
# 360          34,50   0.000000  0.000000
# 546         137,36  51.582759  4.798088
# 726          45,42  51.582759  4.798088
# 1788        158,79  51.622348  3.904958
# 1814        126,98  51.628897  3.913879

# %%
df01.loc[[546, 726], "ZipCode"] = "4818 CK"
df01.loc[[1814], "ZipCode"] = "4301 RJ"

# %%
# van het ene voertuig en die dag er geheel uithalen, want niets bekend over die coordinaten
df02 = df01[
    ~(
        (df01["Date"] == "18-02-2025") &
        (df01["SerialNumber"] == '1313 (VPS-11-J)')
    )
]

df02
# Out:
#          SerialNumber       Date StartRide  Start   Stop Distance TravelTime  \
# 0     1185 (VJL-22-K) 2025-01-03     08:10  08:10  08:42     0,00      00:00
# 1     1185 (VJL-22-K) 2025-01-03     08:42  08:42  08:42     0,00      00:00
# 2     1185 (VJL-22-K) 2025-01-03     08:42  08:42  08:42     0,00      00:00
# 3     1185 (VJL-22-K) 2025-01-03     08:42  08:43  08:43     0,00      00:00
# 4     1185 (VJL-22-K) 2025-01-03     08:43  08:43  08:43     0,00      00:00
# ...               ...        ...       ...    ...    ...      ...        ...
# 2741  1775 (V-11-GGL) 2025-12-31     09:17  09:28  10:18     5,81      00:10
# 2742  1775 (V-11-GGL) 2025-12-31     10:18  10:38  10:57     6,61      00:19
# 2743  1775 (V-11-GGL) 2025-12-31     10:57  11:28  11:46    22,78      00:30
# 2744  1775 (V-11-GGL) 2025-12-31     11:46  11:54  12:02     1,99      00:08
# 2745  1775 (V-11-GGL) 2025-12-31     12:02  12:10  12:21     5,18      00:08
#
#      Duration                        VisitingAddress  \
# 0        0:32       Kamerlingh Onnesweg 9, Dordrecht
# 1        0:00       Kamerlingh Onnesweg 9, Dordrecht
# 2        0:00       Kamerlingh Onnesweg 9, Dordrecht
# 3        0:00       Kamerlingh Onnesweg 9, Dordrecht
# 4        0:00       Kamerlingh Onnesweg 9, Dordrecht
# ...       ...                                    ...
# 2741     0:50        Van Beethovenlaan 56, Rotterdam
# 2742     0:19  Dotterlei 143, Capelle Aan Den Ijssel
# 2743     0:17  Groen Van Prinstererweg 38, Dordrecht
# 2744     0:07               Minnaertweg 4, Dordrecht
# 2745     0:11       Kamerlingh Onnesweg 9, Dordrecht
#
#                     Description    DriverName          GroupName Contact  \
# 0     Medux Kamerlingh Onnesweg           NaN  BBT Dordrecht/MHG     NaN
# 1     Medux Kamerlingh Onnesweg           NaN  BBT Dordrecht/MHG     NaN
# 2     Medux Kamerlingh Onnesweg           NaN  BBT Dordrecht/MHG     NaN
# 3     Medux Kamerlingh Onnesweg           NaN  BBT Dordrecht/MHG     NaN
# 4     Medux Kamerlingh Onnesweg           NaN  BBT Dordrecht/MHG     NaN
# ...                         ...           ...                ...     ...
# 2741                        NaN  Patrick Baas  BBT Dordrecht/MHG     NaN
# 2742                        NaN  Patrick Baas  BBT Dordrecht/MHG     NaN
# 2743                        NaN  Patrick Baas  BBT Dordrecht/MHG     NaN
# 2744                        NaN  Patrick Baas  BBT Dordrecht/MHG     NaN
# 2745  Medux Kamerlingh Onnesweg  Patrick Baas  BBT Dordrecht/MHG     NaN
#
#      Remark                          To  ZipCode                    City  \
# 0       NaN       Kamerlingh Onnesweg 9  3316 GK               Dordrecht
# 1       NaN       Kamerlingh Onnesweg 9  3316 GK               Dordrecht
# 2       NaN       Kamerlingh Onnesweg 9  3316 GK               Dordrecht
# 3       NaN       Kamerlingh Onnesweg 9  3316 GK               Dordrecht
# 4       NaN       Kamerlingh Onnesweg 9  3316 GK               Dordrecht
# ...     ...                         ...      ...                     ...
# 2741    NaN        Van Beethovenlaan 56   3055JD               Rotterdam
# 2742    NaN               Dotterlei 143  2906BC   Capelle Aan Den Ijssel
# 2743    NaN  Groen Van Prinstererweg 38  3317SP                Dordrecht
# 2744    NaN               Minnaertweg 4   3328HN               Dordrecht
# 2745    NaN       Kamerlingh Onnesweg 9  3316 GK               Dordrecht
#
#       ProjectNumber Break TotalTime TotalTravelTime TotalDuration  \
# 0               0.0  0:00      0:32            0:00          0:32
# 1               0.0  0:00      0:32            0:00          0:32
# 2               0.0  0:00      0:32            0:00          0:32
# 3               0.0  0:00      0:32            0:00          0:32
# 4               0.0  0:00      0:33            0:00          0:32
# ...             ...   ...       ...             ...           ...
# 2741            NaN  0:00      3:50            1:27          2:22
# 2742            NaN  0:00      4:29            1:47          2:42
# 2743            NaN  0:00      5:18            2:18          3:00
# 2744            NaN  0:00      5:34            2:26          3:07
# 2745            0.0  0:00      5:53            2:34          3:18
#
#      TotalTimeMinusBreak TotalDistance        Lat      Long
# 0                   0:00          0,00  51.780575  4.638942
# 1                   0:00          0,00  51.780575  4.638942
# 2                   0:00          0,00  51.780575  4.638942
# 3                   0:00          0,00  51.780575  4.638942
# 4                   0:00          0,00  51.780575  4.638942
# ...                  ...           ...        ...       ...
# 2741                0:00         68,85  51.956123  4.512793
# 2742                0:00         75,46  51.932790  4.563842
# 2743                0:00         98,24  51.791025  4.665775
# 2744                0:00        100,23  51.783431  4.686274
# 2745                5:53        105,41  51.780575  4.638942
#
# [2730 rows x 26 columns]

# %%
# rij van traveltime en duration omzetten naar aantal minuten in plaats van string
# Zet om naar timedelta
df02['TravelTime'] = pd.to_timedelta(df02['TravelTime'] + ':00')
df02['Duration'] = pd.to_timedelta(df02['Duration'] + ':00')
df02.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 2730 entries, 0 to 2745
# Data columns (total 26 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   SerialNumber         2730 non-null   str
#  1   Date                 2730 non-null   datetime64[us]
#  2   StartRide            2730 non-null   str
#  3   Start                2730 non-null   str
#  4   Stop                 2730 non-null   str
#  5   Distance             2730 non-null   str
#  6   TravelTime           2730 non-null   timedelta64[us]
#  7   Duration             2730 non-null   timedelta64[us]
#  8   VisitingAddress      2730 non-null   str
#  9   Description          773 non-null    str
#  10  DriverName           2552 non-null   str
#  11  GroupName            2730 non-null   str
#  12  Contact              0 non-null      object
#  13  Remark               0 non-null      str
#  14  To                   2729 non-null   str
#  15  ZipCode              2729 non-null   str
#  16  City                 2730 non-null   str
#  17  ProjectNumber        773 non-null    float64
#  18  Break                2730 non-null   str
#  19  TotalTime            2730 non-null   str
#  20  TotalTravelTime      2730 non-null   str
#  21  TotalDuration        2730 non-null   str
#  22  TotalTimeMinusBreak  2730 non-null   str
#  23  TotalDistance        2730 non-null   str
#  24  Lat                  2730 non-null   float64
#  25  Long                 2730 non-null   float64
# dtypes: datetime64[us](1), float64(3), object(1), str(19), timedelta64[us](2)
# memory usage: 575.9+ KB

# %%
# omzetten naar minuten
df02['TravelTime'] = df02['TravelTime'].dt.total_seconds() // 60
df02['Duration'] = df02['Duration'].dt.total_seconds() // 60

# %%
df02['From'] = (
    df02.groupby(['Date', 'SerialNumber'])['VisitingAddress']
    .shift(1)
)

df02['From'] = df02['From'].fillna(depot_naam)

# %%
df02.head(20)
# Out:
#        SerialNumber       Date StartRide  Start   Stop Distance  TravelTime  \
# 0   1185 (VJL-22-K) 2025-01-03     08:10  08:10  08:42     0,00         0.0
# 1   1185 (VJL-22-K) 2025-01-03     08:42  08:42  08:42     0,00         0.0
# 2   1185 (VJL-22-K) 2025-01-03     08:42  08:42  08:42     0,00         0.0
# 3   1185 (VJL-22-K) 2025-01-03     08:42  08:43  08:43     0,00         0.0
# 4   1185 (VJL-22-K) 2025-01-03     08:43  08:43  08:43     0,00         0.0
# 5   1185 (VJL-22-K) 2025-01-03     08:43  08:45  08:45     0,00         1.0
# 6   1185 (VJL-22-K) 2025-01-03     08:45  08:45  08:45     0,00         0.0
# 7   1185 (VJL-22-K) 2025-01-03     08:45  09:11  09:23    14,16        26.0
# 8   1185 (VJL-22-K) 2025-01-03     09:23  09:29  09:30     2,22         6.0
# 9   1185 (VJL-22-K) 2025-01-03     09:30  09:30  09:50     0,01         0.0
0  Kamerlingh Onnesweg 9, Dordrecht  Medux Kamerlingh Onnesweg
#
#                  DriverName          GroupName Contact Remark  \
# 0                       NaN  BBT Dordrecht/MHG     NaN    NaN
# 1                       NaN  BBT Dordrecht/MHG     NaN    NaN
# 2                       NaN  BBT Dordrecht/MHG     NaN    NaN
# 3                       NaN  BBT Dordrecht/MHG     NaN    NaN
# 4                       NaN  BBT Dordrecht/MHG     NaN    NaN
# ...                     ...                ...     ...    ...
# 2720           Patrick Baas  BBT Dordrecht/MHG     NaN    NaN
# 2721  Geertjan van der Wulp  BBT Dordrecht/MHG     NaN    NaN
# 2734    Peter van den Bosch  BBT Dordrecht/MHG     NaN    NaN
# 2735           Patrick Baas  BBT Dordrecht/MHG     NaN    NaN
# 2736           Patrick Baas  BBT Dordrecht/MHG     NaN    NaN
#
#                          To  ZipCode       City  ProjectNumber Break  \
# 0     Kamerlingh Onnesweg 9  3316 GK  Dordrecht            0.0  0:00
# 1     Kamerlingh Onnesweg 9  3316 GK  Dordrecht            0.0  0:00
# 2     Kamerlingh Onnesweg 9  3316 GK  Dordrecht            0.0  0:00
# 3     Kamerlingh Onnesweg 9  3316 GK  Dordrecht            0.0  0:00
# 4     Kamerlingh Onnesweg 9  3316 GK  Dordrecht            0.0  0:00
# ...                     ...      ...        ...            ...   ...
# 2720  Kamerlingh Onnesweg 9  3316 GK  Dordrecht            0.0  0:00
# 2721  Kamerlingh Onnesweg 9  3316 GK  Dordrecht            0.0  0:00
# 2734  Kamerlingh Onnesweg 9  3316 GK  Dordrecht            0.0  0:00
# 2735  Kamerlingh Onnesweg 9  3316 GK  Dordrecht            0.0  0:00
# 2736  Kamerlingh Onnesweg 9  3316 GK  Dordrecht            0.0  0:00
#
#      TotalTime TotalTravelTime TotalDuration TotalTimeMinusBreak  \
# 0         0:32            0:00          0:32                0:00
# 1         0:32            0:00          0:32                0:00
# 2         0:32            0:00          0:32                0:00
# 3         0:32            0:00          0:32                0:00
# 4         0:33            0:00          0:32                0:00
# ...        ...             ...           ...                 ...
# 2720      0:29            0:29          0:00                0:29
# 2721      0:52            0:12          0:40                0:00
# 2734      4:24            0:18          4:06                4:24
# 2735      0:36            0:23          0:12                0:00
# 2736      1:14            0:24          0:50                0:00
#
#      TotalDistance        Lat      Long                              From
# 0             0,00  51.780575  4.638942  Kamerlingh Onnesweg 9, Dordrecht
# 1             0,00  51.780575  4.638942  Kamerlingh Onnesweg 9, Dordrecht
# 2             0,00  51.780575  4.638942  Kamerlingh Onnesweg 9, Dordrecht
# 3             0,00  51.780575  4.638942  Kamerlingh Onnesweg 9, Dordrecht
# 4             0,00  51.780575  4.638942  Kamerlingh Onnesweg 9, Dordrecht
# ...            ...        ...       ...                               ...
# 2720         24,94  51.780575  4.638942  Kamerlingh Onnesweg 9, Dordrecht
# 2721          6,01  51.780575  4.638942  Kamerlingh Onnesweg 9, Dordrecht
# 2734         14,78  51.780575  4.638942  Kamerlingh Onnesweg 9, Dordrecht
# 2735         25,68  51.780575  4.638942  Kamerlingh Onnesweg 9, Dordrecht
# 2736         25,86  51.780575  4.638942  Kamerlingh Onnesweg 9, Dordrecht
#
# [640 rows x 27 columns]

# %%
(
    (df02['VisitingAddress'] == df02['From']) &
    (df02['VisitingAddress'] == depot_naam)
).sum()
# Out:
# np.int64(529)

# %%
verdacht = df02[
    (df02['VisitingAddress'] == depot_naam) &
    (df02['From'] == depot_naam) &
    (df02['Duration'] > 180)
]

verdacht
# Out:
#          SerialNumber       Date StartRide  Start   Stop Distance  TravelTime  \
# 14    1185 (VJL-22-K) 2025-01-03     13:24  13:25  09:09     0,20         1.0
# 25    1597 (VZT-42-V) 2025-01-03     13:34  13:35  07:25     0,05         0.0
# 39    1702 (V-19-FXR) 2025-01-03     15:18  15:18  08:12     0,00         0.0
# 48    1775 (V-11-GGL) 2025-01-03     10:18  10:19  07:44     0,16         0.0
# 62    1313 (VPS-11-J) 2025-01-06     12:50  12:51  06:27     0,10         1.0
# ...               ...        ...       ...    ...    ...      ...         ...
# 2668  1185 (VJL-22-K) 2025-12-17     16:22  16:22  08:47     0,06         0.0
# 2692  1705 (V-18-FXR) 2025-12-19     16:46  16:47  06:30     0,15         0.0
# 2705   967 (VDG-43-S) 2025-12-23     08:10  08:42  14:36    35,70        31.0
# 2720  1335 (VPP-97-V) 2025-12-30     06:45  07:15  12:32    24,94        29.0
# 2734  1480 (VVF-57-D) 2025-12-31     06:09  06:28  10:34    14,78        18.0
#
#       Duration                   VisitingAddress                Description  \
# 14      4063.0  Kamerlingh Onnesweg 9, Dordrecht  Medux Kamerlingh Onnesweg
# 25      3949.0  Kamerlingh Onnesweg 9, Dordrecht  Medux Kamerlingh Onnesweg
# 39      3894.0  Kamerlingh Onnesweg 9, Dordrecht  Medux Kamerlingh Onnesweg
# 48      5604.0  Kamerlingh Onnesweg 9, Dordrecht  Medux Kamerlingh Onnesweg
# 62      1056.0  Kamerlingh Onnesweg 9, Dordrecht  Medux Kamerlingh Onnesweg
# ...        ...                               ...                        ...
# 2668    2424.0  Kamerlingh Onnesweg 9, Dordrecht  Medux Kamerlingh Onnesweg
# 2692   13783.0  Kamerlingh Onnesweg 9, Dordrecht  Medux Kamerlingh Onnesweg
# 2705     354.0  Kamerlingh Onnesweg 9, Dordrecht  Medux Kamerlingh Onnesweg
# 2720    1757.0  Kamerlingh Onnesweg 9, Dordrecht  Medux Kamerlingh Onnesweg
# 2734     246.0  Kamerlingh Onnesweg 9, Dordrecht  Medux Kamerlingh Onnesweg
#
#                     DriverName          GroupName Contact Remark  \
# 14    Cornelis van der Giessen  BBT Dordrecht/MHG     NaN    NaN
# 25                 Kees Kuiper  BBT Dordrecht/MHG     NaN    NaN
# 39                         NaN  BBT Dordrecht/MHG     NaN    NaN
# 48        Joost van der Linden  BBT Dordrecht/MHG     NaN    NaN
# 62                Robin Kovács  BBT Dordrecht/MHG     NaN    NaN
# ...                        ...                ...     ...    ...
# 2668     Geertjan van der Wulp  BBT Dordrecht/MHG     NaN    NaN
# 2692             Marcus Dekker  BBT Dordrecht/MHG     NaN    NaN
# 2705         Laurens-Jan Burkx  BBT Dordrecht/MHG     NaN    NaN
# 2720              Patrick Baas  BBT Dordrecht/MHG     NaN    NaN
# 2734       Peter van den Bosch  BBT Dordrecht/MHG     NaN    NaN
#
#                          To  ZipCode       City  ProjectNumber Break  \
# 14    Kamerlingh Onnesweg 9  3316 GK  Dordrecht            0.0  0:00
# 25    Kamerlingh Onnesweg 9  3316 GK  Dordrecht            0.0  0:00
# 39    Kamerlingh Onnesweg 9  3316 GK  Dordrecht            0.0  0:00
# 48    Kamerlingh Onnesweg 9  3316 GK  Dordrecht            0.0  0:00
# 62    Kamerlingh Onnesweg 9  3316 GK  Dordrecht            0.0  0:00
# ...                     ...      ...        ...            ...   ...
# 2668  Kamerlingh Onnesweg 9  3316 GK  Dordrecht            0.0  0:00
# 2692  Kamerlingh Onnesweg 9  3316 GK  Dordrecht            0.0  0:00
# 2705  Kamerlingh Onnesweg 9  3316 GK  Dordrecht            0.0  0:00
# 2720  Kamerlingh Onnesweg 9  3316 GK  Dordrecht            0.0  0:00
# 2734  Kamerlingh Onnesweg 9  3316 GK  Dordrecht            0.0  0:00
#
#      TotalTime TotalTravelTime TotalDuration TotalTimeMinusBreak  \
# 14        5:15            2:04          3:11                5:15
# 25        5:40            2:55          2:44                5:40
# 39        8:43            4:18          4:24                8:43
# 48        3:42            1:29          2:13                3:42
# 62        6:27            3:24          3:03                6:27
# ...        ...             ...           ...                 ...
# 2668      8:19            3:56          4:23                8:19
# 2692      9:38            4:49          4:49                9:38
# 2705      6:25            0:31          5:54                0:00
# 2720      0:29            0:29          0:00                0:29
# 2734      4:24            0:18          4:06                4:24
#
#      TotalDistance        Lat      Long                              From
# 14           66,48  51.780575  4.638942  Kamerlingh Onnesweg 9, Dordrecht
# 25           76,78  51.780575  4.638942  Kamerlingh Onnesweg 9, Dordrecht
# 39          312,67  51.780575  4.638942  Kamerlingh Onnesweg 9, Dordrecht
# 48           68,75  51.780575  4.638942  Kamerlingh Onnesweg 9, Dordrecht
# 62           97,90  51.780575  4.638942  Kamerlingh Onnesweg 9, Dordrecht
# ...            ...        ...       ...                               ...
# 2668        116,86  51.780575  4.638942  Kamerlingh Onnesweg 9, Dordrecht
# 2692        282,18  51.780575  4.638942  Kamerlingh Onnesweg 9, Dordrecht
# 2705         35,70  51.780575  4.638942  Kamerlingh Onnesweg 9, Dordrecht
# 2720         24,94  51.780575  4.638942  Kamerlingh Onnesweg 9, Dordrecht
# 2734         14,78  51.780575  4.638942  Kamerlingh Onnesweg 9, Dordrecht
#
# [181 rows x 27 columns]

# %%
df02
# Out:
#          SerialNumber       Date StartRide  Start   Stop Distance  TravelTime  \
# 0     1185 (VJL-22-K) 2025-01-03     08:10  08:10  08:42     0,00         0.0
# 1     1185 (VJL-22-K) 2025-01-03     08:42  08:42  08:42     0,00         0.0
# 2     1185 (VJL-22-K) 2025-01-03     08:42  08:42  08:42     0,00         0.0
# 3     1185 (VJL-22-K) 2025-01-03     08:42  08:43  08:43     0,00         0.0
# 4     1185 (VJL-22-K) 2025-01-03     08:43  08:43  08:43     0,00         0.0
# ...               ...        ...       ...    ...    ...      ...         ...
# 2741  1775 (V-11-GGL) 2025-12-31     09:17  09:28  10:18     5,81        10.0
# 2742  1775 (V-11-GGL) 2025-12-31     10:18  10:38  10:57     6,61        19.0
# 2743  1775 (V-11-GGL) 2025-12-31     10:57  11:28  11:46    22,78        30.0
# 2744  1775 (V-11-GGL) 2025-12-31     11:46  11:54  12:02     1,99         8.0
# 2745  1775 (V-11-GGL) 2025-12-31     12:02  12:10  12:21     5,18         8.0
#
#       Duration                        VisitingAddress  \
# 0         32.0       Kamerlingh Onnesweg 9, Dordrecht
# 1          0.0       Kamerlingh Onnesweg 9, Dordrecht
# 2          0.0       Kamerlingh Onnesweg 9, Dordrecht
# 3          0.0       Kamerlingh Onnesweg 9, Dordrecht
# 4          0.0       Kamerlingh Onnesweg 9, Dordrecht
# ...        ...                                    ...
# 2741      50.0        Van Beethovenlaan 56, Rotterdam
# 2742      19.0  Dotterlei 143, Capelle Aan Den Ijssel
# 2743      17.0  Groen Van Prinstererweg 38, Dordrecht
# 2744       7.0               Minnaertweg 4, Dordrecht
# 2745      11.0       Kamerlingh Onnesweg 9, Dordrecht
#
#                     Description    DriverName          GroupName Contact  \
# 0     Medux Kamerlingh Onnesweg           NaN  BBT Dordrecht/MHG     NaN
# 1     Medux Kamerlingh Onnesweg           NaN  BBT Dordrecht/MHG     NaN
# 2     Medux Kamerlingh Onnesweg           NaN  BBT Dordrecht/MHG     NaN
# 3     Medux Kamerlingh Onnesweg           NaN  BBT Dordrecht/MHG     NaN
# 4     Medux Kamerlingh Onnesweg           NaN  BBT Dordrecht/MHG     NaN
# ...                         ...           ...                ...     ...
# 2741                        NaN  Patrick Baas  BBT Dordrecht/MHG     NaN
# 2742                        NaN  Patrick Baas  BBT Dordrecht/MHG     NaN
# 2743                        NaN  Patrick Baas  BBT Dordrecht/MHG     NaN
# 2744                        NaN  Patrick Baas  BBT Dordrecht/MHG     NaN
# 2745  Medux Kamerlingh Onnesweg  Patrick Baas  BBT Dordrecht/MHG     NaN
#
#      Remark                          To  ZipCode                    City  \
# 0       NaN       Kamerlingh Onnesweg 9  3316 GK               Dordrecht
# 1       NaN       Kamerlingh Onnesweg 9  3316 GK               Dordrecht
# 2       NaN       Kamerlingh Onnesweg 9  3316 GK               Dordrecht
# 3       NaN       Kamerlingh Onnesweg 9  3316 GK               Dordrecht
# 4       NaN       Kamerlingh Onnesweg 9  3316 GK               Dordrecht
# ...     ...                         ...      ...                     ...
# 2741    NaN        Van Beethovenlaan 56   3055JD               Rotterdam
# 2742    NaN               Dotterlei 143  2906BC   Capelle Aan Den Ijssel
# 2743    NaN  Groen Van Prinstererweg 38  3317SP                Dordrecht
# 2744    NaN               Minnaertweg 4   3328HN               Dordrecht
# 2745    NaN       Kamerlingh Onnesweg 9  3316 GK               Dordrecht
#
#       ProjectNumber Break TotalTime TotalTravelTime TotalDuration  \
# 0               0.0  0:00      0:32            0:00          0:32
# 1               0.0  0:00      0:32            0:00          0:32
# 2               0.0  0:00      0:32            0:00          0:32
# 3               0.0  0:00      0:32            0:00          0:32
# 4               0.0  0:00      0:33            0:00          0:32
# ...             ...   ...       ...             ...           ...
# 2741            NaN  0:00      3:50            1:27          2:22
# 2742            NaN  0:00      4:29            1:47          2:42
# 2743            NaN  0:00      5:18            2:18          3:00
# 2744            NaN  0:00      5:34            2:26          3:07
# 2745            0.0  0:00      5:53            2:34          3:18
#
#      TotalTimeMinusBreak TotalDistance        Lat      Long  \
# 0                   0:00          0,00  51.780575  4.638942
# 1                   0:00          0,00  51.780575  4.638942
# 2                   0:00          0,00  51.780575  4.638942
# 3                   0:00          0,00  51.780575  4.638942
# 4                   0:00          0,00  51.780575  4.638942
# ...                  ...           ...        ...       ...
# 2741                0:00         68,85  51.956123  4.512793
# 2742                0:00         75,46  51.932790  4.563842
# 2743                0:00         98,24  51.791025  4.665775
# 2744                0:00        100,23  51.783431  4.686274
# 2745                5:53        105,41  51.780575  4.638942
#
#                                        From
# 0          Kamerlingh Onnesweg 9, Dordrecht
# 1          Kamerlingh Onnesweg 9, Dordrecht
# 2          Kamerlingh Onnesweg 9, Dordrecht
# 3          Kamerlingh Onnesweg 9, Dordrecht
# 4          Kamerlingh Onnesweg 9, Dordrecht
# ...                                     ...
# 2741        Crooswijksesingel 18, Rotterdam
# 2742        Van Beethovenlaan 56, Rotterdam
# 2743  Dotterlei 143, Capelle Aan Den Ijssel
# 2744  Groen Van Prinstererweg 38, Dordrecht
# 2745               Minnaertweg 4, Dordrecht
#
# [2730 rows x 27 columns]

# %% [markdown]
# ## Zorgen dat de dubbele depot naam wordt verwijderd

# %%
import pandas as pd

def clean_depot_rows_start_end(
    df,
    depot_name,
    vehicle_col='SerialNumber',
    date_col='Date',
    address_col='VisitingAddress',
    sort_col='StartRide'
):
    """
    Houdt per voertuig + datum:
    - aan het BEGIN slechts 1 depot-rij over
    - aan het EINDE slechts 1 depot-rij over

    Aaneengesloten dubbele depot-rijen aan begin/einde worden verwijderd.
    """

    df = df.copy()
    df[date_col] = pd.to_datetime(df[date_col], errors='coerce')
    df = df.sort_values([vehicle_col, date_col, sort_col]).copy()

    cleaned_groups = []
    removed_rows = []

    for (veh, dt), group in df.groupby([vehicle_col, date_col], sort=False):
        group = group.copy().reset_index()
        group['_orig_index'] = group['index']
        group = group.drop(columns=['index'])

        # depot indicator
        is_depot = group[address_col].eq(depot_name)

        # -----------------
        # begin van de dag
        # -----------------
        first_non_depot = (~is_depot).idxmax() if (~is_depot).any() else None

        remove_start_idx = []
        if len(group) > 0 and is_depot.iloc[0]:
            if first_non_depot is None:
                # hele dag bestaat alleen uit depot-rijen -> houd 1 rij over
                remove_start_idx = list(range(1, len(group)))
            else:
                # eerste blok depot-rijen: houd alleen de eerste
                if first_non_depot > 1:
                    remove_start_idx = list(range(1, first_non_depot))

        # tijdelijk verwijderen voor analyse einde
        keep_mask = pd.Series(True, index=group.index)
        keep_mask.loc[remove_start_idx] = False
        temp_group = group[keep_mask].copy().reset_index(drop=True)

        is_depot_temp = temp_group[address_col].eq(depot_name)

        # -----------------
        # einde van de dag
        # -----------------
        remove_end_orig_idx = []

        if len(temp_group) > 0 and is_depot_temp.iloc[-1]:
            non_depot_positions = temp_group.index[~is_depot_temp]

            if len(non_depot_positions) == 0:
                # alles is depot -> houd 1 rij over
                remove_end_positions = list(range(1, len(temp_group)))
            else:
                last_non_depot = non_depot_positions.max()
                # alles na laatste niet-depot is eindblok depot
                depot_tail_start = last_non_depot + 1
                if depot_tail_start < len(temp_group) - 1:
                    # houd alleen de eerste depot-rij van het eindblok
                    remove_end_positions = list(range(depot_tail_start + 1, len(temp_group)))
                else:
                    remove_end_positions = []

            remove_end_orig_idx = temp_group.loc[remove_end_positions, '_orig_index'].tolist()
        else:
            remove_end_positions = []

        remove_start_orig_idx = group.loc[remove_start_idx, '_orig_index'].tolist()
        remove_all_orig_idx = set(remove_start_orig_idx + remove_end_orig_idx)

        removed = df.loc[df.index.isin(remove_all_orig_idx)].copy()
        kept = df.loc[
            df.index.isin(group['_orig_index']) & ~df.index.isin(remove_all_orig_idx)
        ].copy()

        removed_rows.append(removed)
        cleaned_groups.append(kept)

    df_clean = pd.concat(cleaned_groups, ignore_index=False).sort_values(
        [vehicle_col, date_col, sort_col]
    )
    df_removed = pd.concat(removed_rows, ignore_index=False).sort_values(
        [vehicle_col, date_col, sort_col]
    )

    return df_clean, df_removed

# %%
df03, df_removed = clean_depot_rows_start_end(
    df=df02,
    depot_name=depot_naam,
    vehicle_col='SerialNumber',
    date_col='Date',
    address_col='VisitingAddress',
    sort_col='StartRide'
)

# %%
print("Aantal verwijderde rijen:", len(df_removed))

print(
    df_removed[['SerialNumber', 'Date', 'VisitingAddress']]
)
# Out:
# Aantal verwijderde rijen: 291
#          SerialNumber       Date                   VisitingAddress
# 898   1001 (VFK-90-R) 2025-04-25  Kamerlingh Onnesweg 9, Dordrecht
# 2259  1026 (VFR-80-J) 2025-10-20  Kamerlingh Onnesweg 9, Dordrecht
# 1307  1047 (VFT-61-Z) 2025-06-20  Kamerlingh Onnesweg 9, Dordrecht
# 1308  1047 (VFT-61-Z) 2025-06-20  Kamerlingh Onnesweg 9, Dordrecht
# 1320  1047 (VFT-61-Z) 2025-06-20  Kamerlingh Onnesweg 9, Dordrecht
# ...               ...        ...                               ...
# 2610  1775 (V-11-GGL) 2025-11-25  Kamerlingh Onnesweg 9, Dordrecht
# 2736  1775 (V-11-GGL) 2025-12-31  Kamerlingh Onnesweg 9, Dordrecht
# 2217   967 (VDG-43-S) 2025-10-14  Kamerlingh Onnesweg 9, Dordrecht
# 2495   967 (VDG-43-S) 2025-11-14  Kamerlingh Onnesweg 9, Dordrecht
# 2706   967 (VDG-43-S) 2025-12-23  Kamerlingh Onnesweg 9, Dordrecht
#
# [291 rows x 3 columns]

# %%
verwijderd_per_route = (
    df_removed
    .groupby(['SerialNumber', 'Date'])
    .size()
    .reset_index(name='aantal_verwijderd')
)

print(verwijderd_per_route)
# Out:
#         SerialNumber       Date  aantal_verwijderd
# 0    1001 (VFK-90-R) 2025-04-25                  1
# 1    1026 (VFR-80-J) 2025-10-20                  1
# 2    1047 (VFT-61-Z) 2025-06-20                  3
# 3    1185 (VJL-22-K) 2025-01-03                  7
# 4    1185 (VJL-22-K) 2025-01-08                  1
# ..               ...        ...                ...
# 167  1775 (V-11-GGL) 2025-11-25                  1
# 168  1775 (V-11-GGL) 2025-12-31                  1
# 169   967 (VDG-43-S) 2025-10-14                  1
# 170   967 (VDG-43-S) 2025-11-14                  1
# 171   967 (VDG-43-S) 2025-12-23                  1
#
# [172 rows x 3 columns]

# %%
print("Origineel:", len(df02))
print("Schoon:", len(df03))
# Out:
# Origineel: 2730
# Schoon: 2439

# %%
controle = (
    df03
    .sort_values(['SerialNumber', 'Date', 'StartRide'])
    .groupby(['SerialNumber', 'Date'])
    .agg(
        eerste_adres=('VisitingAddress', 'first'),
        laatste_adres=('VisitingAddress', 'last'),
        aantal_rijen=('VisitingAddress', 'size')
    )
    .reset_index()
)

controle['start_bij_depot'] = controle['eerste_adres'].eq(depot_naam)
controle['eindigt_bij_depot'] = controle['laatste_adres'].eq(depot_naam)

controle
# Out:
#         SerialNumber       Date                      eerste_adres  \
# 0    1001 (VFK-90-R) 2025-04-25  Kamerlingh Onnesweg 9, Dordrecht
# 1    1001 (VFK-90-R) 2025-08-08  Kamerlingh Onnesweg 9, Dordrecht
# 2    1001 (VFK-90-R) 2025-08-19  Kamerlingh Onnesweg 9, Dordrecht
# 3    1026 (VFR-80-J) 2025-10-20  Kamerlingh Onnesweg 9, Dordrecht
# 4    1026 (VFR-80-J) 2025-10-30  Kamerlingh Onnesweg 9, Dordrecht
# ..               ...        ...                               ...
# 229   967 (VDG-43-S) 2025-10-23  Kamerlingh Onnesweg 9, Dordrecht
# 230   967 (VDG-43-S) 2025-11-07  Kamerlingh Onnesweg 9, Dordrecht
# 231   967 (VDG-43-S) 2025-11-14  Kamerlingh Onnesweg 9, Dordrecht
# 232   967 (VDG-43-S) 2025-11-21  Kamerlingh Onnesweg 9, Dordrecht
# 233   967 (VDG-43-S) 2025-12-23  Kamerlingh Onnesweg 9, Dordrecht
#
#                         laatste_adres  aantal_rijen  start_bij_depot  \
# 0    Kamerlingh Onnesweg 9, Dordrecht            10             True
# 1    Kamerlingh Onnesweg 9, Dordrecht             4             True
# 2    Kamerlingh Onnesweg 9, Dordrecht             1             True
# 3    Kamerlingh Onnesweg 9, Dordrecht             1             True
# 4    Kamerlingh Onnesweg 9, Dordrecht             1             True
# ..                                ...           ...              ...
# 229  Kamerlingh Onnesweg 9, Dordrecht             5             True
# 230  Kamerlingh Onnesweg 9, Dordrecht             1             True
# 231  Kamerlingh Onnesweg 9, Dordrecht             1             True
# 232  Kamerlingh Onnesweg 9, Dordrecht             1             True
# 233  Kamerlingh Onnesweg 9, Dordrecht             1             True
#
#      eindigt_bij_depot
# 0                 True
# 1                 True
# 2                 True
# 3                 True
# 4                 True
# ..                 ...
# 229               True
# 230               True
# 231               True
# 232               True
# 233               True
#
# [234 rows x 7 columns]

# %%
controle['correct'] = (
    controle['start_bij_depot'] &
    controle['eindigt_bij_depot']
)

# %%
goede_routes = controle[controle['correct']]
print(goede_routes)
# Out:
#         SerialNumber       Date                      eerste_adres  \
# 0    1001 (VFK-90-R) 2025-04-25  Kamerlingh Onnesweg 9, Dordrecht
# 1    1001 (VFK-90-R) 2025-08-08  Kamerlingh Onnesweg 9, Dordrecht
# 2    1001 (VFK-90-R) 2025-08-19  Kamerlingh Onnesweg 9, Dordrecht
# 3    1026 (VFR-80-J) 2025-10-20  Kamerlingh Onnesweg 9, Dordrecht
# 4    1026 (VFR-80-J) 2025-10-30  Kamerlingh Onnesweg 9, Dordrecht
# ..               ...        ...                               ...
# 229   967 (VDG-43-S) 2025-10-23  Kamerlingh Onnesweg 9, Dordrecht
# 230   967 (VDG-43-S) 2025-11-07  Kamerlingh Onnesweg 9, Dordrecht
# 231   967 (VDG-43-S) 2025-11-14  Kamerlingh Onnesweg 9, Dordrecht
# 232   967 (VDG-43-S) 2025-11-21  Kamerlingh Onnesweg 9, Dordrecht
# 233   967 (VDG-43-S) 2025-12-23  Kamerlingh Onnesweg 9, Dordrecht
#
#                         laatste_adres  aantal_rijen  start_bij_depot  \
# 0    Kamerlingh Onnesweg 9, Dordrecht            10             True
# 1    Kamerlingh Onnesweg 9, Dordrecht             4             True
# 2    Kamerlingh Onnesweg 9, Dordrecht             1             True
# 3    Kamerlingh Onnesweg 9, Dordrecht             1             True
# 4    Kamerlingh Onnesweg 9, Dordrecht             1             True
# ..                                ...           ...              ...
# 229  Kamerlingh Onnesweg 9, Dordrecht             5             True
# 230  Kamerlingh Onnesweg 9, Dordrecht             1             True
# 231  Kamerlingh Onnesweg 9, Dordrecht             1             True
# 232  Kamerlingh Onnesweg 9, Dordrecht             1             True
# 233  Kamerlingh Onnesweg 9, Dordrecht             1             True
#
#      eindigt_bij_depot  correct
# 0                 True     True
# 1                 True     True
# 2                 True     True
# 3                 True     True
# 4                 True     True
# ..                 ...      ...
# 229               True     True
# 230               True     True
# 231               True     True
# 232               True     True
# 233               True     True
#
# [234 rows x 8 columns]

# %% [markdown]
# ## Rij met missende waarde

# %%
# kijken naar de rij met de andere missende waarde
gekozen_datum = "14-08-2025"
gekozen_serial = "1705 (V-18-FXR)"

subset = df03[
    (df03["Date"] == gekozen_datum) &
    (df03["SerialNumber"] == gekozen_serial)
]

# %%
# van het ene voertuig en die dag er geheel uithalen, want niets bekend over die coordinaten
df04 = df03[
    ~(
        (df03["Date"] == "14-08-2025") &
        (df03["SerialNumber"] == '1705 (V-18-FXR)')
    )
]

df04
# Out:
#          SerialNumber       Date StartRide  Start   Stop Distance  TravelTime  \
# 888   1001 (VFK-90-R) 2025-04-25     06:59  07:13  07:44    12,97        14.0
# 889   1001 (VFK-90-R) 2025-04-25     07:44  08:20  09:55    41,04        36.0
# 890   1001 (VFK-90-R) 2025-04-25     09:55  10:15  10:42    17,60        20.0
# 891   1001 (VFK-90-R) 2025-04-25     10:42  10:48  10:55     0,00         5.0
# 892   1001 (VFK-90-R) 2025-04-25     10:55  11:55  12:25    41,82        60.0
# ...               ...        ...       ...    ...    ...      ...         ...
# 2291   967 (VDG-43-S) 2025-10-23     15:51  16:53  07:15    36,10        61.0
# 2416   967 (VDG-43-S) 2025-11-07     08:56  09:38  08:37    35,70        41.0
# 2494   967 (VDG-43-S) 2025-11-14     09:41  11:12  11:14   107,20        91.0
# 2577   967 (VDG-43-S) 2025-11-21     07:02  07:03  08:49     0,10         1.0
# 2705   967 (VDG-43-S) 2025-12-23     08:10  08:42  14:36    35,70        31.0
#
#       Duration                        VisitingAddress  \
# 888       30.0       Kamerlingh Onnesweg 9, Dordrecht
# 889       94.0               Onyxdijk 183, Roosendaal
# 889                 0:00         54,01  51.518541  4.491785
# 890                 0:00         71,61  51.506608  4.293024
# 891                 0:00         71,61  51.506608  4.293024
# 892                 0:00        113,43  51.757658  4.167531
# ...                  ...           ...        ...       ...
# 2291                9:50         79,00  51.780575  4.638942
# 2416              170:32        119,20  51.780575  4.638942
# 2494                0:00        107,20  51.780575  4.638942
# 2577              165:22        107,50  51.780575  4.638942
# 2705                0:00         35,70  51.780575  4.638942
#
#                                      From
# 888      Kamerlingh Onnesweg 9, Dordrecht
# 889      Kamerlingh Onnesweg 9, Dordrecht
# 890              Onyxdijk 183, Roosendaal
# 891   Lambertijnenhof 212, Bergen Op Zoom
# 892   Lambertijnenhof 212, Bergen Op Zoom
# ...                                   ...
# 2291      Sint Liduinastraat 15, Schiedam
# 2416     Kamerlingh Onnesweg 9, Dordrecht
# 2494     Kamerlingh Onnesweg 9, Dordrecht
# 2577     Kamerlingh Onnesweg 9, Dordrecht
# 2705     Kamerlingh Onnesweg 9, Dordrecht
#
# [2425 rows x 27 columns]

# %% [markdown]
# ## Model 3

# %%
df04['Date'].unique()
# Out:
# <DatetimeArray>
# ['2025-04-25 00:00:00', '2025-08-08 00:00:00', '2025-08-19 00:00:00',
#  '2025-10-20 00:00:00', '2025-10-30 00:00:00', '2025-06-05 00:00:00',
#  '2025-06-20 00:00:00', '2025-07-17 00:00:00', '2025-01-03 00:00:00',
#  '2025-01-08 00:00:00',
#  ...
#  '2025-02-19 00:00:00', '2025-03-05 00:00:00', '2025-04-01 00:00:00',
#  '2025-05-22 00:00:00', '2025-06-30 00:00:00', '2025-07-15 00:00:00',
#  '2025-08-11 00:00:00', '2025-10-13 00:00:00', '2025-11-10 00:00:00',
#  '2025-11-07 00:00:00']
# Length: 163, dtype: datetime64[us]

# %%
result = df04.groupby('Date')['SerialNumber'].nunique()
result
# Out:
# Date
# 2025-01-03    4
# 2025-01-06    2
# 2025-01-07    1
# 2025-01-08    2
# 2025-01-10    1
#              ..
# 2025-12-23    2
# 2025-12-27    1
# 2025-12-29    1
# 2025-12-30    1
# 2025-12-31    3
# Name: SerialNumber, Length: 163, dtype: int64

# %%
max_datum = result.idxmax()
max_aantal = result.max()

print("Datum met meeste aantal voertuigen:", max_datum)
print("Aantal unieke voertuigen:", max_aantal)
# Out:
# Datum met meeste aantal voertuigen: 2025-01-03 00:00:00
# Aantal unieke voertuigen: 4

# %%
df05 = df04[df04['Date'] == max_datum]
df05
# Out:
#        SerialNumber       Date StartRide  Start   Stop Distance  TravelTime  \
# 0   1185 (VJL-22-K) 2025-01-03     08:10  08:10  08:42     0,00         0.0
# 7   1185 (VJL-22-K) 2025-01-03     08:45  09:11  09:23    14,16        26.0
# 8   1185 (VJL-22-K) 2025-01-03     09:23  09:29  09:30     2,22         6.0
# 9   1185 (VJL-22-K) 2025-01-03     09:30  09:30  09:50     0,01         0.0
# 10  1185 (VJL-22-K) 2025-01-03     09:50  09:55  10:06     1,57         4.0
# 11  1185 (VJL-22-K) 2025-01-03     10:06  10:19  10:33     4,14        12.0
# 34          3:37                0:00        203,46  51.504090  3.611025
# 35          4:15                0:00        204,25  51.499649  3.612773
# 36          4:21                0:00        312,64  51.780575  4.638942
# 40          0:08                0:00         36,04  51.780575  4.638942
# 42          1:13                0:00         44,65  51.815547  4.630499
# 43          1:16                0:00         57,43  51.807925  4.686165
# 44          1:43                0:00         60,03  51.792806  4.682687
# 45          1:47                0:00         62,61  51.783431  4.686274
# 46          2:09                0:00         65,19  51.791025  4.665775
# 47          2:13                0:00         68,59  51.780575  4.638942
#
#                                          From
# 0            Kamerlingh Onnesweg 9, Dordrecht
# 7            Kamerlingh Onnesweg 9, Dordrecht
# 8                      Touwbaan 4, Sliedrecht
# 9                   Kerkbuurt 220, Sliedrecht
# 10                  Kerkbuurt 220, Sliedrecht
# 11                  Kerkbuurt 143, Sliedrecht
# 12  Jupiterstraat 257, Hardinxveld-Giessendam
# 13                     Banneweg 57, Gorinchem
# 15           Kamerlingh Onnesweg 9, Dordrecht
# 16           Kamerlingh Onnesweg 9, Dordrecht
# 17                  Oosterhagen 17, Rotterdam
# 18            Boergoensestraat 128, Rotterdam
# 19              Maashaven O.Z. 103, Rotterdam
# 20                  Motorstraat 96, Rotterdam
# 21            Haastrechtstraat 130, Rotterdam
# 22                  Pietersdijk 60, Rotterdam
# 23                  Oosterhagen 17, Rotterdam
# 24                     Reling 19, Barendrecht
# 26           Kamerlingh Onnesweg 9, Dordrecht
# 27           Kamerlingh Onnesweg 9, Dordrecht
# 28                       De Poort 24, Rilland
# 29                     Vliete 1, Krabbendijke
# 30                      Rooseveltlaan 1, Axel
# 31                   Molenstraat 95, Zaamslag
# 32                 Pattistpark 137, Terneuzen
# 33                     Bachlaan 88, Terneuzen
# 34                   Agaat 2 -12 , Middelburg
# 35                Noordbolwerk 33, Middelburg
# 36       Latijnse Schoolstraat 19, Middelburg
# 40           Kamerlingh Onnesweg 9, Dordrecht
# 42           Kamerlingh Onnesweg 9, Dordrecht
# 43                 Plantageweg 3, Zwijndrecht
# 44                 Bankastraat 158, Dordrecht
# 45       Albert Schweitzerplaats 1, Dordrecht
# 46                   Minnaertweg 4, Dordrecht
# 47      Groen Van Prinstererweg 38, Dordrecht

# %%
import time
import numpy as np
import pandas as pd
from math import radians, sin, cos, sqrt, atan2
from ortools.constraint_solver import pywrapcp, routing_enums_pb2

# %% [markdown]
# ## Model 3

# %%
# ==============================
# INSTELLINGEN
# ==============================

gekozen_datum = max_datum    # kies hier de dag
depot_adres = depot_naam
depot_lat = 51.780575
depot_long = 4.638942

TIME_LIMIT_SECONDS = 10
MAX_ADRESSEN_PER_BUS = 15
MAX_ROUTE_TIME_MIN = 8 * 60      # bijvoorbeeld 8 uur
GEM_SNELHEID_KM_U = 40           # voor omrekenen afstand -> reistijd

# %%
# ==============================
# DATA VOORBEREIDEN
# ==============================

df = df05.copy()

# Datum netjes omzetten
df['Date'] = pd.to_datetime(df['Date'], errors='coerce')

#
# LOCATIES OPBOUWEN
# ==============================

depot_df = pd.DataFrame({
    'VisitingAddress': [depot_adres],
    'Lat': [depot_lat],
    'Long': [depot_long]
})

# Unieke klantlocaties van die dag
locations = (
    df_dag[['VisitingAddress', 'Lat', 'Long']]
    .dropna(subset=['VisitingAddress', 'Lat', 'Long'])
    .drop_duplicates()
    .reset_index(drop=True)
)

# Depot bovenaan zetten
locations = pd.concat([depot_df, locations], ignore_index=True)

# Dubbele adressen verwijderen, depot blijft dan bovenaan staan
locations = locations.drop_duplicates(subset=['VisitingAddress']).reset_index(drop=True)

# Node id
locations['node_id'] = locations.index

print("Aantal locaties incl. depot:", len(locations))
display(locations.head())
# Out:
# Aantal locaties incl. depot: 27
#                              VisitingAddress        Lat      Long  node_id
# 0           Kamerlingh Onnesweg 9, Dordrecht  51.780575  4.638942        0
# 1                     Touwbaan 4, Sliedrecht  51.826966  4.749114        1
# 2                  Kerkbuurt 220, Sliedrecht  51.823225  4.768590        2
# 3                  Kerkbuurt 143, Sliedrecht  51.823264  4.770902        3
# 4  Jupiterstraat 257, Hardinxveld-Giessendam  51.823749  4.822809        4

# %%
# ==============================
# SERVICETIJDEN PER ADRES
# ==============================

service_times_df = (
    df_dag.groupby('VisitingAddress', as_index=False)['Duration']
    .median()
    .rename(columns={'Duration': 'service_time'})
)

service_times_df['service_time'] = (
    service_times_df['service_time']
    .fillna(0)
    .round()
    .astype(int)
)

# Koppelen aan locaties
locations = locations.merge(service_times_df, on='VisitingAddress', how='left')
locations['service_time'] = locations['service_time'].fillna(0).astype(int)

# Depot heeft geen servicetijd
locations.loc[locations['VisitingAddress'] == depot_adres, 'service_time'] = 0

print("Servicetijden toegevoegd")
display(locations.head())
# Out:
# Servicetijden toegevoegd
#                              VisitingAddress        Lat      Long  node_id  \
# 0           Kamerlingh Onnesweg 9, Dordrecht  51.780575  4.638942        0
# 1                     Touwbaan 4, Sliedrecht  51.826966  4.749114        1
# 2                  Kerkbuurt 220, Sliedrecht  51.823225  4.768590        2
# 3                  Kerkbuurt 143, Sliedrecht  51.823264  4.770902        3
# 4  Jupiterstraat 257, Hardinxveld-Giessendam  51.823749  4.822809        4
#
#    service_time
# 0             0
# 1            11
# 2            10
# 3            11
# 4            14

# %%
# ==============================
# AFSTANDSBEREKENING
# ==============================

def haversine(lat1, lon1, lat2, lon2):
    R = 6371  # km
    dlat = radians(lat2 - lat1)
    dlon = radians(lon2 - lon1)

    a = sin(dlat / 2)**2 + cos(radians(lat1)) * cos(radians(lat2)) * sin(dlon / 2)**2
    c = 2 * atan2(sqrt(a), sqrt(1 - a))
    return R * c

# %%
# ==============================
# DISTANCE MATRIX
# ==============================

n = len(locations)
distance_matrix = np.zeros((n, n))

for i in range(n):
    for j in range(n):
        distance_matrix[i, j] = haversine(
            locations.loc[i, 'Lat'],
            locations.loc[i, 'Long'],
            locations.loc[j, 'Lat'],
            locations.loc[j, 'Long']
        )

# OR-Tools werkt liever met integers
distance_matrix = (distance_matrix * 1000).astype(int)  # meters

print("distance_matrix shape:", distance_matrix.shape)
# Out:
# distance_matrix shape: (27, 27)

# %%
# ==============================
# TIME MATRIX
# ==============================

time_matrix = np.round(
    (distance_matrix / 1000) / GEM_SNELHEID_KM_U * 60
).astype(int)

print("time_matrix shape:", time_matrix.shape)
# Out:
# time_matrix shape: (27, 27)

# %%
# ==============================
# CAPACITEIT
# ==============================

num_vehicles = df_dag['SerialNumber'].nunique()

demands = [0] + [1] * (len(locations) - 1)
vehicle_capacities = [MAX_ADRESSEN_PER_BUS] * num_vehicles

service_times = locations['service_time'].tolist()

print("Aantal voertuigen:", num_vehicles)
print("Lengte demands:", len(demands))
print("Lengte service_times:", len(service_times))
# Out:
# Aantal voertuigen: 4
# Lengte demands: 27
# Lengte service_times: 27

# %%
# ==============================
# STRATEGIEËN
# ==============================

first_solution_strategies = {
    "PATH_CHEAPEST_ARC": routing_enums_pb2.FirstSolutionStrategy.PATH_CHEAPEST_ARC,
    "PARALLEL_CHEAPEST_INSERTION": routing_enums_pb2.FirstSolutionStrategy.PARALLEL_CHEAPEST_INSERTION,
    "LOCAL_CHEAPEST_INSERTION": routing_enums_pb2.FirstSolutionStrategy.LOCAL_CHEAPEST_INSERTION,
    "GLOBAL_CHEAPEST_ARC": routing_enums_pb2.FirstSolutionStrategy.GLOBAL_CHEAPEST_ARC,
    "LOCAL_CHEAPEST_ARC": routing_enums_pb2.FirstSolutionStrategy.LOCAL_CHEAPEST_ARC,
    "SAVINGS": routing_enums_pb2.FirstSolutionStrategy.SAVINGS,
}

local_search_metaheuristics = {
    "GREEDY_DESCENT": routing_enums_pb2.LocalSearchMetaheuristic.GREEDY_DESCENT,
    "GUIDED_LOCAL_SEARCH": routing_enums_pb2.LocalSearchMetaheuristic.GUIDED_LOCAL_SEARCH,
    "SIMULATED_ANNEALING": routing_enums_pb2.LocalSearchMetaheuristic.SIMULATED_ANNEALING,
    "TABU_SEARCH": routing_enums_pb2.LocalSearchMetaheuristic.TABU_SEARCH,
}

# %%
# ==============================
# MODEL 3 BOUWEN
# ==============================

def build_model_3(time_matrix,
                  distance_matrix,
                  num_vehicles,
                  demands,
                  vehicle_capacities,
                  service_times,
                  depot=0,
                  max_route_time=8*60):

    manager = pywrapcp.RoutingIndexManager(
        len(distance_matrix),
        num_vehicles,
        [depot] * num_vehicles,
        [depot] * num_vehicles
    )

    routing = pywrapcp.RoutingModel(manager)

    # --------------------------
    # afstand callback
    # --------------------------
    def distance_callback(from_index, to_index):
        from_node = manager.IndexToNode(from_index)
        to_node = manager.IndexToNode(to_index)
        return int(distance_matrix[from_node][to_node])

    distance_callback_index = routing.RegisterTransitCallback(distance_callback)
    routing.SetArcCostEvaluatorOfAllVehicles(distance_callback_index)

    # --------------------------
    # demand callback
    # --------------------------
    def demand_callback(from_index):
        from_node = manager.IndexToNode(from_index)
        return demands[from_node]

    demand_callback_index = routing.RegisterUnaryTransitCallback(demand_callback)

    routing.AddDimensionWithVehicleCapacity(
        demand_callback_index,
        0,
        vehicle_capacities,
        True,
        "Capacity"
    )

    # --------------------------
    # time callback
    # tijd = reistijd + servicetijd op huidige node
    # --------------------------
    def time_callback(from_index, to_index):
        from_node = manager.IndexToNode(from_index)
        to_node = manager.IndexToNode(to_index)

        travel_time = time_matrix[from_node][to_node]
        service_time = service_times[from_node]

        return int(travel_time + service_time)

    time_callback_index = routing.RegisterTransitCallback(time_callback)

    routing.AddDimension(
        time_callback_index,
        0,                # meer wachttijd toegestaan
        max_route_time,   # maximale route-duur
        True,             # start op 0
        "Time"
    )

    return manager, routing

# %%
# ==============================
# TOTALE AFSTAND
# ==============================

def calculate_total_distance(solution, routing, num_vehicles):
    total_distance = 0

    for vehicle_id in range(num_vehicles):
        index = routing.Start(vehicle_id)
        while not routing.IsEnd(index):
            next_index = solution.Value(routing.NextVar(index))
            total_distance += routing.GetArcCostForVehicle(index, next_index, vehicle_id)
            index = next_index

    return total_distance

# %%
# ==============================
# ROUTES UITLEZEN
# ==============================

def extract_model_3_routes(solution, manager, routing, num_vehicles, locations, demands):
    totaal_afstand = 0
    routes_output = []

    time_dimension = routing.GetDimensionOrDie("Time")

    for vehicle_id in range(num_vehicles):
        index = routing.Start(vehicle_id)
        route_nodes = []
        route_adressen = []
        route_distance = 0
        route_demand = 0

        while not routing.IsEnd(index):
            node = manager.IndexToNode(index)
            route_nodes.append(node)
            route_adressen.append(locations.loc[node, 'VisitingAddress'])
            route_demand += demands[node]

            previous_index = index
            index = solution.Value(routing.NextVar(index))
            route_distance += routing.GetArcCostForVehicle(previous_index, index, vehicle_id)

        end_node = manager.IndexToNode(index)
        route_nodes.append(end_node)
        route_adressen.append(locations.loc[end_node, 'VisitingAddress'])

        totaal_afstand += route_distance
        eindtijd = solution.Value(time_dimension.CumulVar(index))

        routes_output.append({
            "vehicle_id": vehicle_id,
            "route_nodes": route_nodes,
            "route_adressen": route_adressen,
            "aantal_adressen": route_demand,
            "afstand_meters": route_distance,
            "afstand_km": round(route_distance / 1000, 2),
            "totale_tijd_min": eindtijd,
            "totale_tijd_uur": round(eindtijd / 60, 2)
        })

    return totaal_afstand, routes_output

# %%
# ==============================
# ALLE COMBINATIES TESTEN
# ==============================

def compare_model_3_strategies(time_matrix,
                               distance_matrix,
                               num_vehicles,
                               demands,
                               vehicle_capacities,
                               service_times,
                               first_solution_strategies,
                               local_search_metaheuristics,
                               time_limit_seconds=10,
                               max_route_time=8*60):
    results = []

    for fs_name, fs_value in first_solution_strategies.items():
        for ls_name, ls_value in local_search_metaheuristics.items():

            print(f"Testen: {fs_name} + {ls_name}")

            manager, routing = build_model_3(
                time_matrix=time_matrix,
                distance_matrix=distance_matrix,
                num_vehicles=num_vehicles,
                demands=demands,
                vehicle_capacities=vehicle_capacities,
                service_times=service_times,
                depot=0,
                max_route_time=max_route_time
            )

            search_parameters = pywrapcp.DefaultRoutingSearchParameters()
            search_parameters.first_solution_strategy = fs_value
            search_parameters.local_search_metaheuristic = ls_value
            search_parameters.time_limit.seconds = time_limit_seconds

            start = time.time()
            solution = routing.SolveWithParameters(search_parameters)
            runtime = time.time() - start

            if solution:
                total_distance = calculate_total_distance(solution, routing, num_vehicles)

                used_vehicles = 0
                time_dimension = routing.GetDimensionOrDie("Time")
                max_time_used = 0

                for vehicle_id in range(num_vehicles):
                    start_index = routing.Start(vehicle_id)
                    next_index = solution.Value(routing.NextVar(start_index))

                    if not routing.IsEnd(next_index):
                        used_vehicles += 1

                    end_index = routing.End(vehicle_id)
                    route_time = solution.Value(time_dimension.CumulVar(end_index))
                    max_time_used = max(max_time_used, route_time)

                results.append({
                    "first_solution_strategy": fs_name,
                    "local_search_metaheuristic": ls_name,
                    "solution_found": True,
                    "total_distance": total_distance,
                    "used_vehicles": used_vehicles,
                    "max_route_time_min": max_time_used,
                    "runtime_sec": round(runtime, 2),
                })
            else:
                results.append({
                    "first_solution_strategy": fs_name,
                    "local_search_metaheuristic": ls_name,
                    "solution_found": False,
                    "total_distance": None,
                    "used_vehicles": None,
                    "max_route_time_min": None,
                    "runtime_sec": round(runtime, 2),
                })

    df_results = pd.DataFrame(results)

    df_results = df_results.sort_values(
        by=["solution_found", "total_distance", "runtime_sec"],
        ascending=[False, True, True]
    ).reset_index(drop=True)

    return df_results

# %%
# ==============================
# BESTE COMBINATIE KIEZEN
# ==============================

def get_best_parameters(df_results, allow_zero_distance=False):
    df_valid = df_results[df_results["solution_found"] == True].copy()
    df_valid = df_valid[df_valid["total_distance"].notna()]

    if not allow_zero_distance:
        df_valid = df_valid[df_valid["total_distance"] > 0]

    if df_valid.empty:
        raise ValueError(
            "Geen geldige oplossing gevonden voor Model 3. "
            "Controleer je data, capaciteit en route-tijdrestrictie."
        )

    best_row = df_valid.sort_values(
        by=["total_distance", "runtime_sec"],
        ascending=[True, True]
    ).iloc[0]

    return best_row["first_solution_strategy"], best_row["local_search_metaheuristic"]

# %%
# ==============================
# MODEL 3 TESTEN
# ==============================

df_results_model3 = compare_model_3_strategies(
    time_matrix=time_matrix,
    distance_matrix=distance_matrix,
    num_vehicles=num_vehicles,
    demands=demands,
    vehicle_capacities=vehicle_capacities,
    service_times=service_times,
    first_solution_strategies=first_solution_strategies,
    local_search_metaheuristics=local_search_metaheuristics,
    time_limit_seconds=TIME_LIMIT_SECONDS,
    max_route_time=MAX_ROUTE_TIME_MIN
)

print("Top 10 beste combinaties voor MODEL 3:")
display(df_results_model3.head(10))
# Out:
# Testen: PATH_CHEAPEST_ARC + GREEDY_DESCENT
# Testen: PATH_CHEAPEST_ARC + GUIDED_LOCAL_SEARCH
# Testen: PATH_CHEAPEST_ARC + SIMULATED_ANNEALING
# Testen: PATH_CHEAPEST_ARC + TABU_SEARCH
# Testen: PARALLEL_CHEAPEST_INSERTION + GREEDY_DESCENT
# Testen: PARALLEL_CHEAPEST_INSERTION + GUIDED_LOCAL_SEARCH
# Testen: PARALLEL_CHEAPEST_INSERTION + SIMULATED_ANNEALING
# Testen: PARALLEL_CHEAPEST_INSERTION + TABU_SEARCH
# Testen: LOCAL_CHEAPEST_INSERTION + GREEDY_DESCENT
# Testen: LOCAL_CHEAPEST_INSERTION + GUIDED_LOCAL_SEARCH
# Testen: LOCAL_CHEAPEST_INSERTION + SIMULATED_ANNEALING
# Testen: LOCAL_CHEAPEST_INSERTION + TABU_SEARCH
# Testen: GLOBAL_CHEAPEST_ARC + GREEDY_DESCENT
# Testen: GLOBAL_CHEAPEST_ARC + GUIDED_LOCAL_SEARCH
# Testen: GLOBAL_CHEAPEST_ARC + SIMULATED_ANNEALING
# Testen: GLOBAL_CHEAPEST_ARC + TABU_SEARCH
# Testen: LOCAL_CHEAPEST_ARC + GREEDY_DESCENT
# Testen: LOCAL_CHEAPEST_ARC + GUIDED_LOCAL_SEARCH
# Testen: LOCAL_CHEAPEST_ARC + SIMULATED_ANNEALING
# Testen: LOCAL_CHEAPEST_ARC + TABU_SEARCH
# Testen: SAVINGS + GREEDY_DESCENT
# Testen: SAVINGS + GUIDED_LOCAL_SEARCH
# Testen: SAVINGS + SIMULATED_ANNEALING
# Testen: SAVINGS + TABU_SEARCH
# Top 10 beste combinaties voor MODEL 3:
#        first_solution_strategy local_search_metaheuristic  solution_found  \
# 0          GLOBAL_CHEAPEST_ARC             GREEDY_DESCENT            True
# 1            PATH_CHEAPEST_ARC             GREEDY_DESCENT            True
# 2          GLOBAL_CHEAPEST_ARC                TABU_SEARCH            True
# 3           LOCAL_CHEAPEST_ARC             GREEDY_DESCENT            True
# 4                      SAVINGS                TABU_SEARCH            True
# 5            PATH_CHEAPEST_ARC                TABU_SEARCH            True
# 6           LOCAL_CHEAPEST_ARC                TABU_SEARCH            True
# 7            PATH_CHEAPEST_ARC        SIMULATED_ANNEALING            True
# 8            PATH_CHEAPEST_ARC        GUIDED_LOCAL_SEARCH            True
# 9  PARALLEL_CHEAPEST_INSERTION        GUIDED_LOCAL_SEARCH            True
#
#    total_distance  used_vehicles  max_route_time_min  runtime_sec
# 0          390991              3                 479         0.04
# 1          390991              3                 479         0.05
# 2          390991              3                 479         0.68
# 3          390991              3                 479         0.80
# 4          390991              3                 479         1.52
# 5          390991              3                 479         2.53
# 6          390991              3                 479         4.44
# 7          390991              3                 479         9.99
# 8          390991              3                 479        10.00
# 9          390991              3                 479        10.00

# %%
best_fs3, best_ls3 = get_best_parameters(df_results_model3, allow_zero_distance=False)

print("Beste combinatie voor MODEL 3:")
print("FirstSolutionStrategy:", best_fs3)
print("LocalSearchMetaheuristic:", best_ls3)
# Out:
# Beste combinatie voor MODEL 3:
# FirstSolutionStrategy: GLOBAL_CHEAPEST_ARC
# LocalSearchMetaheuristic: GREEDY_DESCENT

# %%
# ==============================
# MODEL 3 DEFINITIEF DRAAIEN
# ==============================

manager3, routing3 = build_model_3(
    time_matrix=time_matrix,
    distance_matrix=distance_matrix,
    num_vehicles=num_vehicles,
    demands=demands,
    vehicle_capacities=vehicle_capacities,
    service_times=service_times,
    depot=0,
    max_route_time=MAX_ROUTE_TIME_MIN
)

search_parameters3 = pywrapcp.DefaultRoutingSearchParameters()
search_parameters3.first_solution_strategy = getattr(
    routing_enums_pb2.FirstSolutionStrategy, best_fs3
)
search_parameters3.local_search_metaheuristic = getattr(
    routing_enums_pb2.LocalSearchMetaheuristic, best_ls3
)
search_parameters3.time_limit.seconds = TIME_LIMIT_SECONDS

solution3 = routing3.SolveWithParameters(search_parameters3)

# %%
# ==============================
# RESULTATEN MODEL 3
# ==============================

if solution3:
    totaal_afstand3, routes_output3 = extract_model_3_routes(
        solution=solution3,
        manager=manager3,
        routing=routing3,
        num_vehicles=num_vehicles,
        locations=locations,
        demands=demands
    )

    print(f"\nMODEL 3: Totaal aantal voertuigen: {num_vehicles}")
    print(f"MODEL 3: Totaal aantal locaties incl. depot: {len(locations)}")
    print(f"MODEL 3: Totale afstand: {round(totaal_afstand3 / 1000, 2)} km\n")

    for route in routes_output3:
        print(f"Bus {route['vehicle_id']}:")
        print(" -> ".join(route['route_adressen']))
        print(f"Aantal adressen: {route['aantal_adressen']}")
        print(f"Afstand: {route['afstand_km']} km")
        print(f"Totale tijd: {route['totale_tijd_min']} min ({route['totale_tijd_uur']} uur)")
        print("-" * 60)

else:
    print("MODEL 3: Geen oplossing gevonden.")
# Out:
# MODEL 3: Totaal aantal voertuigen: 4
# MODEL 3: Totaal aantal locaties incl. depot: 27
# MODEL 3: Totale afstand: 390.99 km
#
# Bus 0:
# Kamerlingh Onnesweg 9, Dordrecht -> Plantageweg 3, Zwijndrecht -> Bankastraat 158, Dordrecht -> Touwbaan 4, Sliedrecht -> Kerkbuurt 220, Sliedrecht -> Kerkbuurt 143, Sliedrecht -> Jupiterstraat 257, Hardinxveld-Giessendam -> Banneweg 57, Gorinchem -> Minnaertweg 4, Dordrecht -> Albert Schweitzerplaats 1, Dordrecht -> Groen Van Prinstererweg 38, Dordrecht -> Kamerlingh Onnesweg 9, Dordrecht
# Aantal adressen: 10
# Afstand: 51.15 km
# Totale tijd: 304 min (5.07 uur)
# ------------------------------------------------------------
# Bus 1:
# Kamerlingh Onnesweg 9, Dordrecht -> Kamerlingh Onnesweg 9, Dordrecht
# Aantal adressen: 0
# Afstand: 0.0 km
# Totale tijd: 0 min (0.0 uur)
# ------------------------------------------------------------
# Bus 2:
# Kamerlingh Onnesweg 9, Dordrecht -> Vliete 1, Krabbendijke -> Pattistpark 137, Terneuzen -> Bachlaan 88, Terneuzen -> Rooseveltlaan 1, Axel -> Molenstraat 95, Zaamslag -> De Poort 24, Rilland -> Kamerlingh Onnesweg 9, Dordrecht
# Aantal adressen: 6
# Afstand: 161.72 km
# Totale tijd: 382 min (6.37 uur)
# ------------------------------------------------------------
# Bus 3:
# Kamerlingh Onnesweg 9, Dordrecht -> Pietersdijk 60, Rotterdam -> Oosterhagen 17, Rotterdam -> Haastrechtstraat 130, Rotterdam -> Motorstraat 96, Rotterdam -> Maashaven O.Z. 103, Rotterdam -> Boergoensestraat 128, Rotterdam -> Reling 19, Barendrecht -> Noordbolwerk 33, Middelburg -> Latijnse Schoolstraat 19, Middelburg -> Agaat 2 -12 , Middelburg -> Kamerlingh Onnesweg 9, Dordrecht
# Aantal adressen: 10
# Afstand: 178.12 km
# Totale tijd: 479 min (7.98 uur)
# ------------------------------------------------------------

# %% [markdown]
# ## Model 4

# %%
gekozen_datum = max_datum    # kies hier de dag
depot_adres = depot_naam
depot_lat = 51.780575
depot_long = 4.638942

TIME_LIMIT_SECONDS = 10
MAX_ADRESSEN_PER_BUS = 15
GEM_SNELHEID_KM_U = 40           # voor reistijd-benadering

# Depot time window
DEPOT_OPEN = 8 * 60              # 08:00
DEPOT_CLOSE = 16 * 60            # 18:00

# %%
df = df05.copy()

df['Date'] = pd.to_datetime(df['Date'], errors='coerce')
gekozen_datum = pd.to_datetime(gekozen_datum)

df_dag = df[df['Date'].dt.date == gekozen_datum.date()].copy()

print("Aantal rijen in df_dag:", len(df_dag))
print("Aantal voertuigen:", df_dag['SerialNumber'].nunique())

display(df_dag.head())
# Out:
# Aantal rijen in df_dag: 36
# Aantal voertuigen: 4
#        SerialNumber       Date StartRide  Start   Stop Distance  TravelTime  \
# 0   1185 (VJL-22-K) 2025-01-03     08:10  08:10  08:42     0,00         0.0
# 7   1185 (VJL-22-K) 2025-01-03     08:45  09:11  09:23    14,16        26.0
# 8   1185 (VJL-22-K) 2025-01-03     09:23  09:29  09:30     2,22         6.0
# 9   1185 (VJL-22-K) 2025-01-03     09:30  09:30  09:50     0,01         0.0
# 10  1185 (VJL-22-K) 2025-01-03     09:50  09:55  10:06     1,57         4.0
#
#     Duration                   VisitingAddress                Description  \
# 0       32.0  Kamerlingh Onnesweg 9, Dordrecht  Medux Kamerlingh Onnesweg
# 7       11.0            Touwbaan 4, Sliedrecht                        NaN
# 8        0.0         Kerkbuurt 220, Sliedrecht                        NaN
# 9       19.0         Kerkbuurt 220, Sliedrecht                        NaN
# 10      11.0         Kerkbuurt 143, Sliedrecht                        NaN
#
#                   DriverName          GroupName Contact Remark  \
# 0                        NaN  BBT Dordrecht/MHG     NaN    NaN
# 7   Cornelis van der Giessen  BBT Dordrecht/MHG     NaN    NaN
# 8   Cornelis van der Giessen  BBT Dordrecht/MHG     NaN    NaN
# 9   Cornelis van der Giessen  BBT Dordrecht/MHG     NaN    NaN
# 10  Cornelis van der Giessen  BBT Dordrecht/MHG     NaN    NaN
#
#                        To  ZipCode        City  ProjectNumber Break TotalTime  \
# 0   Kamerlingh Onnesweg 9  3316 GK   Dordrecht            0.0  0:00      0:32
# 7              Touwbaan 4  3363WB   Sliedrecht            NaN  0:00      1:13
# 8           Kerkbuurt 220  3361BM   Sliedrecht            NaN  0:00      1:20
# 9           Kerkbuurt 220  3361BM   Sliedrecht            NaN  0:00      1:40
# 10          Kerkbuurt 143  3361BE   Sliedrecht            NaN  0:00      1:56
#
#    TotalTravelTime TotalDuration TotalTimeMinusBreak TotalDistance        Lat  \
# 0             0:00          0:32                0:00          0,00  51.780575
# 7             0:28          0:44                0:00         14,16  51.826966
# 8             0:35          0:45                0:00         16,38  51.823225
# 9             0:35          1:05                0:00         16,39  51.823225
# 10            0:39          1:16                0:00         17,96  51.823264
#
#         Long                              From
# 0   4.638942  Kamerlingh Onnesweg 9, Dordrecht
# 7   4.749114  Kamerlingh Onnesweg 9, Dordrecht
# 8   4.768590            Touwbaan 4, Sliedrecht
# 9   4.768590         Kerkbuurt 220, Sliedrecht
# 10  4.770902         Kerkbuurt 220, Sliedrecht

# %%
depot_df = pd.DataFrame({
    'VisitingAddress': [depot_adres],
    'Lat': [depot_lat],
    'Long': [depot_long]
})

locations = (
    df_dag[['VisitingAddress', 'Lat', 'Long']]
    .dropna(subset=['VisitingAddress', 'Lat', 'Long'])
    .drop_duplicates()
    .reset_index(drop=True)
)

locations = pd.concat([depot_df, locations], ignore_index=True)
locations = locations.drop_duplicates(subset=['VisitingAddress']).reset_index(drop=True)

locations['node_id'] = locations.index

print("Aantal locaties incl. depot:", len(locations))
display(locations.head())
# Out:
# Aantal locaties incl. depot: 27
#                              VisitingAddress        Lat      Long  node_id
# 0           Kamerlingh Onnesweg 9, Dordrecht  51.780575  4.638942        0
# 1                     Touwbaan 4, Sliedrecht  51.826966  4.749114        1
# 2                  Kerkbuurt 220, Sliedrecht  51.823225  4.768590        2
# 3                  Kerkbuurt 143, Sliedrecht  51.823264  4.770902        3
# 4  Jupiterstraat 257, Hardinxveld-Giessendam  51.823749  4.822809        4

# %%
service_times_df = (
    df_dag.groupby('VisitingAddress', as_index=False)['Duration']
    .median()
    .rename(columns={'Duration': 'service_time'})
)

service_times_df['service_time'] = (
    service_times_df['service_time']
    .fillna(0)
    .round()
    .astype(int)
)

locations = locations.merge(service_times_df, on='VisitingAddress', how='left')
locations['service_time'] = locations['service_time'].fillna(0).astype(int)

# depot heeft geen servicetijd
locations.loc[locations['VisitingAddress'] == depot_adres, 'service_time'] = 0

display(locations.head())
# Out:
#                              VisitingAddress        Lat      Long  node_id  \
# 0           Kamerlingh Onnesweg 9, Dordrecht  51.780575  4.638942        0
# 1                     Touwbaan 4, Sliedrecht  51.826966  4.749114        1
# 2                  Kerkbuurt 220, Sliedrecht  51.823225  4.768590        2
# 3                  Kerkbuurt 143, Sliedrecht  51.823264  4.770902        3
# 4  Jupiterstraat 257, Hardinxveld-Giessendam  51.823749  4.822809        4
#
#    service_time
# 0             0
# 1            11
# 2            10
# 3            11
# 4            14

# %%
def haversine(lat1, lon1, lat2, lon2):
    R = 6371  # km
    dlat = radians(lat2 - lat1)
    dlon = radians(lon2 - lon1)

    a = sin(dlat / 2)**2 + cos(radians(lat1)) * cos(radians(lat2)) * sin(dlon / 2)**2
    c = 2 * atan2(sqrt(a), sqrt(1 - a))
    return R * c

# %%
n = len(locations)
distance_matrix = np.zeros((n, n))

for i in range(n):
    for j in range(n):
        distance_matrix[i, j] = haversine(
            locations.loc[i, 'Lat'],
            locations.loc[i, 'Long'],
            locations.loc[j, 'Lat'],
            locations.loc[j, 'Long']
        )

distance_matrix = (distance_matrix * 1000).astype(int)   # meters

print(distance_matrix.shape)
# Out:
# (27, 27)

# %%
# TIME MATRIX
# ==============================

time_matrix = np.round(
    (distance_matrix / 1000) / GEM_SNELHEID_KM_U * 60
).astype(int)

print(time_matrix.shape)
# Out:
# (27, 27)

# %%
# CAPACITEIT EN SERVICE
# ==============================

num_vehicles = df_dag['SerialNumber'].nunique()

demands = [0] + [1] * (len(locations) - 1)
vehicle_capacities = [MAX_ADRESSEN_PER_BUS] * num_vehicles

service_times = locations['service_time'].tolist()

print("Aantal voertuigen:", num_vehicles)
print("Lengte demands:", len(demands))
print("Lengte service_times:", len(service_times))
# Out:
# Aantal voertuigen: 4
# Lengte demands: 27
# Lengte service_times: 27

# %%
# TIME WINDOWS
# ==============================

locations['window_start'] = 8 * 60   # 08:00
locations['window_end'] = 16 * 60    # 18:00

# depot apart
locations.loc[locations['VisitingAddress'] == depot_adres, 'window_start'] = 8 * 60
locations.loc[locations['VisitingAddress'] == depot_adres, 'window_end'] = 16 * 60

time_windows = list(zip(locations['window_start'], locations['window_end']))


display(locations[['node_id', 'VisitingAddress', 'window_start', 'window_end']].head(10))
# Out:
#    node_id                            VisitingAddress  window_start  \
# 0        0           Kamerlingh Onnesweg 9, Dordrecht           480
# 1        1                     Touwbaan 4, Sliedrecht           480
# 2        2                  Kerkbuurt 220, Sliedrecht           480
# 3        3                  Kerkbuurt 143, Sliedrecht           480
# 4        4  Jupiterstraat 257, Hardinxveld-Giessendam           480
# 5        5                     Banneweg 57, Gorinchem           480
# 6        6                  Oosterhagen 17, Rotterdam           480
# 7        7            Boergoensestraat 128, Rotterdam           480
# 8        8              Maashaven O.Z. 103, Rotterdam           480
# 9        9                  Motorstraat 96, Rotterdam           480
#
#    window_end
# 0         960
# 1         960
# 2         960
# 3         960
# 4         960
# 5         960
# 6         960
# 7         960
# 8         960
# 9         960

# %%
first_solution_strategies = {
    "PATH_CHEAPEST_ARC": routing_enums_pb2.FirstSolutionStrategy.PATH_CHEAPEST_ARC,
    "PARALLEL_CHEAPEST_INSERTION": routing_enums_pb2.FirstSolutionStrategy.PARALLEL_CHEAPEST_INSERTION,
    "LOCAL_CHEAPEST_INSERTION": routing_enums_pb2.FirstSolutionStrategy.LOCAL_CHEAPEST_INSERTION,
    "GLOBAL_CHEAPEST_ARC": routing_enums_pb2.FirstSolutionStrategy.GLOBAL_CHEAPEST_ARC,
    "LOCAL_CHEAPEST_ARC": routing_enums_pb2.FirstSolutionStrategy.LOCAL_CHEAPEST_ARC,
    "SAVINGS": routing_enums_pb2.FirstSolutionStrategy.SAVINGS,
}

local_search_metaheuristics = {
    "GREEDY_DESCENT": routing_enums_pb2.LocalSearchMetaheuristic.GREEDY_DESCENT,
    "GUIDED_LOCAL_SEARCH": routing_enums_pb2.LocalSearchMetaheuristic.GUIDED_LOCAL_SEARCH,
    "SIMULATED_ANNEALING": routing_enums_pb2.LocalSearchMetaheuristic.SIMULATED_ANNEALING,
    "TABU_SEARCH": routing_enums_pb2.LocalSearchMetaheuristic.TABU_SEARCH,
}

# %%
# ==============================
# MODEL 4 BOUWEN
# ==============================

def build_model_4(time_matrix,
                  distance_matrix,
                  num_vehicles,
                  demands,
                  vehicle_capacities,
                  service_times,
                  time_windows,
                  depot=0):

    manager = pywrapcp.RoutingIndexManager(
        len(distance_matrix),
        num_vehicles,
        [depot] * num_vehicles,
        [depot] * num_vehicles
    )

    routing = pywrapcp.RoutingModel(manager)

    def distance_callback(from_index, to_index):
        from_node = manager.IndexToNode(from_index)
        to_node = manager.IndexToNode(to_index)
        return int(distance_matrix[from_node][to_node])

    distance_callback_index = routing.RegisterTransitCallback(distance_callback)
    routing.SetArcCostEvaluatorOfAllVehicles(distance_callback_index)

    def demand_callback(from_index):
        from_node = manager.IndexToNode(from_index)
        return demands[from_node]

    demand_callback_index = routing.RegisterUnaryTransitCallback(demand_callback)

    routing.AddDimensionWithVehicleCapacity(
        demand_callback_index,
        0,
        vehicle_capacities,
        True,
        "Capacity"
    )

    def time_callback(from_index, to_index):
        from_node = manager.IndexToNode(from_index)
        to_node = manager.IndexToNode(to_index)

        travel_time = time_matrix[from_node][to_node]
        service_time = service_times[from_node]

        return int(travel_time + service_time)

    time_callback_index = routing.RegisterTransitCallback(time_callback)

    routing.AddDimension(
        time_callback_index,
        12 * 60,    # ruime wachttijd
        24 * 60,    # volledige daghorizon
        False,
        "Time"
    )

    time_dimension = routing.GetDimensionOrDie("Time")

    # klanten
    for node in range(1, len(time_windows)):
        index = manager.NodeToIndex(node)
        start, end = time_windows[node]
        time_dimension.CumulVar(index).SetRange(int(start), int(end))

    # depot per voertuig
    depot_start, depot_end = time_windows[0]
    for vehicle_id in range(num_vehicles):
        start_index = routing.Start(vehicle_id)
        end_index = routing.End(vehicle_id)

        time_dimension.CumulVar(start_index).SetRange(int(depot_start), int(depot_end))
        time_dimension.CumulVar(end_index).SetRange(int(depot_start), int(depot_end))

    return manager, routing

# %%
# ==============================
# TOTALE AFSTAND
# ==============================

def calculate_total_distance(solution, routing, num_vehicles):
    total_distance = 0

    for vehicle_id in range(num_vehicles):
        index = routing.Start(vehicle_id)
        while not routing.IsEnd(index):
            next_index = solution.Value(routing.NextVar(index))
            total_distance += routing.GetArcCostForVehicle(index, next_index, vehicle_id)
            index = next_index

    return total_distance

# %%
# ==============================
# ==============================
# ROUTES UITLEZEN
# ==============================

def extract_model_4_routes(
    solution,
    manager,
    routing,
    num_vehicles,
    locations,
    demands,
    time_matrix
):
    totaal_afstand = 0
    routes_output = []

    time_dimension = routing.GetDimensionOrDie("Time")

    for vehicle_id in range(num_vehicles):
        start_index = routing.Start(vehicle_id)
        first_next = solution.Value(routing.NextVar(start_index))

        vehicle_used = not routing.IsEnd(first_next)

        index = start_index
        route_nodes = []
        route_adressen = []
        route_times = []
        route_travel_times = []
        route_service_times = []

        route_distance = 0
        route_demand = 0

        start_time = solution.Value(time_dimension.CumulVar(start_index))

        while not routing.IsEnd(index):
            node = manager.IndexToNode(index)
            tijd = solution.Value(time_dimension.CumulVar(index))

            route_nodes.append(node)
            route_adressen.append(locations.loc[node, "VisitingAddress"])
            route_times.append(tijd)
            route_demand += demands[node]

            # servicetijd op huidige locatie
            service_time = locations.loc[node, "service_time"]
            route_service_times.append(service_time)

            previous_index = index
            index = solution.Value(routing.NextVar(index))

            next_node = manager.IndexToNode(index)

            # rijtijd van huidige locatie naar volgende locatie
            travel_time = time_matrix[node][next_node]
            route_travel_times.append(travel_time)

            # afstand van huidige locatie naar volgende locatie
            route_distance += routing.GetArcCostForVehicle(
                previous_index,
                index,
                vehicle_id
            )

        end_node = manager.IndexToNode(index)
        end_time = solution.Value(time_dimension.CumulVar(index))

        route_nodes.append(end_node)
        route_adressen.append(locations.loc[end_node, "VisitingAddress"])
        route_times.append(end_time)

        # einddepot: meestal geen service/rijtijd meer tonen
        route_service_times.append(0)
        route_travel_times.append(0)

        totaal_afstand += route_distance

        if not vehicle_used:
            start_time_report = 0
            end_time_report = 0
            route_duration = 0
            route_times_report = [0, 0]
        else:
            start_time_report = start_time
            end_time_report = end_time
            route_duration = end_time - start_time
            route_times_report = route_times

        routes_output.append({
            "vehicle_id": vehicle_id,
            "vehicle_used": vehicle_used,
            "route_nodes": route_nodes,
            "route_adressen": route_adressen,
            "route_times_min": route_times_report,
            "route_travel_times_min": route_travel_times,
            "route_service_times_min": route_service_times,
            "aantal_adressen": route_demand,
            "afstand_meters": route_distance,
            "afstand_km": round(route_distance / 1000, 2),
            "start_tijd_min": start_time_report,
            "eind_tijd_min": end_time_report,
            "totale_tijd_min": route_duration,
            "totale_tijd_uur": round(route_duration / 60, 2)
        })

    return totaal_afstand, routes_output

# %%
# ==============================
# COMBINATIES TESTEN
# ==============================

def compare_model_4_strategies(time_matrix,
                               distance_matrix,
                               num_vehicles,
                               demands,
                               vehicle_capacities,
                               service_times,
                               time_windows,
                               first_solution_strategies,
                               local_search_metaheuristics,
                               time_limit_seconds=10
                               ):

    results = []

    for fs_name, fs_value in first_solution_strategies.items():
        for ls_name, ls_value in local_search_metaheuristics.items():

            print(f"Testen: {fs_name} + {ls_name}")

            manager, routing = build_model_4(
                time_matrix=time_matrix,
                distance_matrix=distance_matrix,
                num_vehicles=num_vehicles,
                demands=demands,
                vehicle_capacities=vehicle_capacities,
                service_times=service_times,
                time_windows=time_windows,
                depot=0
            )

            search_parameters = pywrapcp.DefaultRoutingSearchParameters()
            search_parameters.first_solution_strategy = fs_value
            search_parameters.local_search_metaheuristic = ls_value
            search_parameters.time_limit.seconds = time_limit_seconds

            start = time.time()
            solution = routing.SolveWithParameters(search_parameters)
            runtime = time.time() - start

            if solution:
                total_distance = calculate_total_distance(solution, routing, num_vehicles)

                used_vehicles = 0
                time_dimension = routing.GetDimensionOrDie("Time")
                max_time_used = 0

                for vehicle_id in range(num_vehicles):
                    start_index = routing.Start(vehicle_id)
                    next_index = solution.Value(routing.NextVar(start_index))

                    if not routing.IsEnd(next_index):
                        used_vehicles += 1

                    end_index = routing.End(vehicle_id)
                    route_time = solution.Value(time_dimension.CumulVar(end_index))
                    max_time_used = max(max_time_used, route_time)

                results.append({
                    "first_solution_strategy": fs_name,
                    "local_search_metaheuristic": ls_name,
                    "solution_found": True,
                    "total_distance": total_distance,
                    "used_vehicles": used_vehicles,
                    "max_route_time_min": max_time_used,
                    "runtime_sec": round(runtime, 2),
                })
            else:
                results.append({
                    "first_solution_strategy": fs_name,
                    "local_search_metaheuristic": ls_name,
                    "solution_found": False,
                    "total_distance": None,
                    "used_vehicles": None,
                    "max_route_time_min": None,
                    "runtime_sec": round(runtime, 2),
                })

    df_results = pd.DataFrame(results)

    df_results = df_results.sort_values(
        by=["solution_found", "total_distance", "runtime_sec"],
        ascending=[False, True, True]
    ).reset_index(drop=True)

    return df_results

# %%
# ==============================
# BESTE COMBINATIE
# ==============================

def get_best_parameters(df_results, allow_zero_distance=False):
    df_valid = df_results[df_results["solution_found"] == True].copy()
    df_valid = df_valid[df_valid["total_distance"].notna()]

    if not allow_zero_distance:
        df_valid = df_valid[df_valid["total_distance"] > 0]

    if df_valid.empty:
        raise ValueError(
            "Geen geldige oplossing gevonden voor Model 4. "
            "Controleer capaciteit, time windows en maximale routeduur."
        )

    best_row = df_valid.sort_values(
        by=["total_distance", "runtime_sec"],
        ascending=[True, True]
    ).iloc[0]

    return best_row["first_solution_strategy"], best_row["local_search_metaheuristic"]

# %%
print(locations[['VisitingAddress', 'service_time']].sort_values('service_time', ascending=False).head(20))
print("Totale service_time:", locations['service_time'].sum())
# Out:
#                               VisitingAddress  service_time
# 5                      Banneweg 57, Gorinchem            94
# 9                   Motorstraat 96, Rotterdam            56
# 17                 Pattistpark 137, Terneuzen            51
# 18                     Bachlaan 88, Terneuzen            46
# 21       Latijnse Schoolstraat 19, Middelburg            38
# 22                 Plantageweg 3, Zwijndrecht            34
# 10            Haastrechtstraat 130, Rotterdam            32
# 20                Noordbolwerk 33, Middelburg            26
# 24       Albert Schweitzerplaats 1, Dordrecht            26
# 19                   Agaat 2 -12 , Middelburg            22
# 16                   Molenstraat 95, Zaamslag            22
# 26      Groen Van Prinstererweg 38, Dordrecht            21
# 15                      Rooseveltlaan 1, Axel            14
# 4   Jupiterstraat 257, Hardinxveld-Giessendam            14
# 6                   Oosterhagen 17, Rotterdam            13
# 11                  Pietersdijk 60, Rotterdam            12
# 1                      Touwbaan 4, Sliedrecht            11
# 3                   Kerkbuurt 143, Sliedrecht            11
# 2                   Kerkbuurt 220, Sliedrecht            10
# 7             Boergoensestraat 128, Rotterdam             9
# Totale service_time: 580

# %%
print(locations[locations['VisitingAddress'] == depot_adres])
print("Aantal keer depot in locations:", (locations['VisitingAddress'] == depot_adres).sum())
# Out:
#                     VisitingAddress        Lat      Long  node_id  \
# 0  Kamerlingh Onnesweg 9, Dordrecht  51.780575  4.638942        0
#
#    service_time  window_start  window_end
# 0             0           480         960
# Aantal keer depot in locations: 1

# %%
print("Aantal locaties:", len(locations))
print("Aantal klanten excl depot:", len(locations) - 1)
print("Aantal voertuigen:", num_vehicles)
print("Totale vraag:", sum(demands))
print("Totale capaciteit:", sum(vehicle_capacities))
print("Depot count:", (locations['VisitingAddress'] == depot_adres).sum())
print(locations[['VisitingAddress', 'service_time', 'window_start', 'window_end']].head(20))
# Out:
# Aantal locaties: 27
# Aantal klanten excl depot: 26
# Aantal voertuigen: 4
# Totale vraag: 26
# Totale capaciteit: 60
# Depot count: 1
#                               VisitingAddress  service_time  window_start  \
# 0            Kamerlingh Onnesweg 9, Dordrecht             0           480
# 1                      Touwbaan 4, Sliedrecht            11           480
# 2                   Kerkbuurt 220, Sliedrecht            10           480
# 3                   Kerkbuurt 143, Sliedrecht            11           480
# 4   Jupiterstraat 257, Hardinxveld-Giessendam            14           480
# 5                      Banneweg 57, Gorinchem            94           480
# 6                   Oosterhagen 17, Rotterdam            13           480
# 7             Boergoensestraat 128, Rotterdam             9           480
# 8               Maashaven O.Z. 103, Rotterdam             0           480
# 9                   Motorstraat 96, Rotterdam            56           480
# 10            Haastrechtstraat 130, Rotterdam            32           480
# 11                  Pietersdijk 60, Rotterdam            12           480
# 12                     Reling 19, Barendrecht             5           480
# 13                       De Poort 24, Rilland             2           480
# 14                     Vliete 1, Krabbendijke             4           480
# 15                      Rooseveltlaan 1, Axel            14           480
# 16                   Molenstraat 95, Zaamslag            22           480
# 17                 Pattistpark 137, Terneuzen            51           480
# 18                     Bachlaan 88, Terneuzen            46           480
# 19                   Agaat 2 -12 , Middelburg            22           480
#
#     window_end
# 0          960
# 1          960
# 2          960
# 3          960
# 4          960
# 5          960
# 6          960
# 7          960
# 8          960
# 9          960
# 10         960
# 11         960
# 12         960
# 13         960
# 14         960
# 15         960
# 16         960
# 17         960
# 18         960
# 19         960

# %%
# ==============================
# MODEL 4 TESTEN
# ==============================

df_results_model4 = compare_model_4_strategies(
    time_matrix=time_matrix,
    distance_matrix=distance_matrix,
    num_vehicles=num_vehicles,
    demands=demands,
    vehicle_capacities=vehicle_capacities,
    service_times=service_times,
    time_windows=time_windows,
    first_solution_strategies=first_solution_strategies,
    local_search_metaheuristics=local_search_metaheuristics,
    time_limit_seconds=TIME_LIMIT_SECONDS,
)

print("Top 10 beste combinaties voor MODEL 4:")
display(df_results_model4.head(10))
# Out:
# Testen: PATH_CHEAPEST_ARC + GREEDY_DESCENT
# Testen: PATH_CHEAPEST_ARC + GUIDED_LOCAL_SEARCH
# Testen: PATH_CHEAPEST_ARC + SIMULATED_ANNEALING
# Testen: PATH_CHEAPEST_ARC + TABU_SEARCH
# Testen: PARALLEL_CHEAPEST_INSERTION + GREEDY_DESCENT
# Testen: PARALLEL_CHEAPEST_INSERTION + GUIDED_LOCAL_SEARCH
# Testen: PARALLEL_CHEAPEST_INSERTION + SIMULATED_ANNEALING
# Testen: PARALLEL_CHEAPEST_INSERTION + TABU_SEARCH
# Testen: LOCAL_CHEAPEST_INSERTION + GREEDY_DESCENT
# Testen: LOCAL_CHEAPEST_INSERTION + GUIDED_LOCAL_SEARCH
# Testen: LOCAL_CHEAPEST_INSERTION + SIMULATED_ANNEALING
# Testen: LOCAL_CHEAPEST_INSERTION + TABU_SEARCH
# Testen: GLOBAL_CHEAPEST_ARC + GREEDY_DESCENT
# Testen: GLOBAL_CHEAPEST_ARC + GUIDED_LOCAL_SEARCH
# Testen: GLOBAL_CHEAPEST_ARC + SIMULATED_ANNEALING
# Testen: GLOBAL_CHEAPEST_ARC + TABU_SEARCH
# Testen: LOCAL_CHEAPEST_ARC + GREEDY_DESCENT
# Testen: LOCAL_CHEAPEST_ARC + GUIDED_LOCAL_SEARCH
# Testen: LOCAL_CHEAPEST_ARC + SIMULATED_ANNEALING
# Testen: LOCAL_CHEAPEST_ARC + TABU_SEARCH
# Testen: SAVINGS + GREEDY_DESCENT
# Testen: SAVINGS + GUIDED_LOCAL_SEARCH
# Testen: SAVINGS + SIMULATED_ANNEALING
# Testen: SAVINGS + TABU_SEARCH
# Top 10 beste combinaties voor MODEL 4:
#   first_solution_strategy local_search_metaheuristic  solution_found  \
# 0     GLOBAL_CHEAPEST_ARC             GREEDY_DESCENT            True
# 1       PATH_CHEAPEST_ARC             GREEDY_DESCENT            True
# 2     GLOBAL_CHEAPEST_ARC                TABU_SEARCH            True
# 3      LOCAL_CHEAPEST_ARC             GREEDY_DESCENT            True
# 4                 SAVINGS                TABU_SEARCH            True
# 5       PATH_CHEAPEST_ARC                TABU_SEARCH            True
# 6      LOCAL_CHEAPEST_ARC                TABU_SEARCH            True
# 7      LOCAL_CHEAPEST_ARC        SIMULATED_ANNEALING            True
# 8       PATH_CHEAPEST_ARC        GUIDED_LOCAL_SEARCH            True
# 9       PATH_CHEAPEST_ARC        SIMULATED_ANNEALING            True
#
#    total_distance  used_vehicles  max_route_time_min  runtime_sec
# 0          390991              3                 959         0.05
# 1          390991              3                 959         0.08
# 2          390991              3                 959         0.77
# 3          390991              3                 959         0.93
# 4          390991              3                 959         1.61
# 5          390991              3                 959         2.68
# 6          390991              3                 959         4.85
# 7          390991              3                 959         9.99
# 8          390991              3                 959        10.00
# 9          390991              3                 959        10.00

# %%
best_fs4, best_ls4 = get_best_parameters(df_results_model4, allow_zero_distance=False)

print("Beste combinatie voor MODEL 4:")
print("FirstSolutionStrategy:", best_fs4)
print("LocalSearchMetaheuristic:", best_ls4)
# Out:
# Beste combinatie voor MODEL 4:
# FirstSolutionStrategy: GLOBAL_CHEAPEST_ARC
# LocalSearchMetaheuristic: GREEDY_DESCENT

# %%
# ==============================
# MODEL 4 DEFINITIEF DRAAIEN
# ==============================

manager4, routing4 = build_model_4(
    time_matrix=time_matrix,
    distance_matrix=distance_matrix,
    num_vehicles=num_vehicles,
    demands=demands,
    vehicle_capacities=vehicle_capacities,
    service_times=service_times,
    time_windows=time_windows,
    depot=0,
)

search_parameters4 = pywrapcp.DefaultRoutingSearchParameters()
search_parameters4.first_solution_strategy = getattr(
    routing_enums_pb2.FirstSolutionStrategy, best_fs4
)
search_parameters4.local_search_metaheuristic = getattr(
    routing_enums_pb2.LocalSearchMetaheuristic, best_ls4
)
search_parameters4.time_limit.seconds = TIME_LIMIT_SECONDS

solution4 = routing4.SolveWithParameters(search_parameters4)

# %%
# ==============================
# RESULTATEN MODEL 4
# ==============================

if solution4:
    totaal_afstand4, routes_output4 = extract_model_4_routes(
        solution=solution4,
        manager=manager4,
        routing=routing4,
        num_vehicles=num_vehicles,
        locations=locations,
        demands=demands,
        time_matrix=time_matrix
    )

    print(f"\nMODEL 4: Totale afstand: {round(totaal_afstand4 / 1000, 2)} km\n")

    for route in routes_output4:
        print(f"Bus {route['vehicle_id']}:")
        for adres, tijd in zip(route['route_adressen'], route['route_times_min']):
            uur = tijd // 60
            minuut = tijd % 60
            print(f"{adres} @ {uur:02d}:{minuut:02d}")

        print(f"Aantal adressen: {route['aantal_adressen']}")
        print(f"Afstand: {route['afstand_km']} km")
        print(f"Totale tijd: {route['totale_tijd_min']} min ({route['totale_tijd_uur']} uur)")
        print("-" * 60)

else:
    print("MODEL 4: Geen oplossing gevonden.")
# Out:
# MODEL 4: Totale afstand: 390.99 km
#
# Bus 0:
# Kamerlingh Onnesweg 9, Dordrecht @ 08:00
# Plantageweg 3, Zwijndrecht @ 08:06
# Bankastraat 158, Dordrecht @ 08:46
# Touwbaan 4, Sliedrecht @ 08:56
# Kerkbuurt 220, Sliedrecht @ 09:09
# Kerkbuurt 143, Sliedrecht @ 09:19
# Jupiterstraat 257, Hardinxveld-Giessendam @ 09:35
# Banneweg 57, Gorinchem @ 10:03
# Minnaertweg 4, Dordrecht @ 12:06
# Albert Schweitzerplaats 1, Dordrecht @ 12:12
# Groen Van Prinstererweg 38, Dordrecht @ 12:40
# Kamerlingh Onnesweg 9, Dordrecht @ 13:04
# Aantal adressen: 10
# Afstand: 51.15 km
# Totale tijd: 304 min (5.07 uur)
# ------------------------------------------------------------
# Bus 1:
# Kamerlingh Onnesweg 9, Dordrecht @ 00:00
# Kamerlingh Onnesweg 9, Dordrecht @ 00:00
# Aantal adressen: 0
# Afstand: 0.0 km
# Totale tijd: 0 min (0.0 uur)
# ------------------------------------------------------------
# Bus 2:
# Kamerlingh Onnesweg 9, Dordrecht @ 08:00
# Vliete 1, Krabbendijke @ 09:22
# Pattistpark 137, Terneuzen @ 09:55
# Bachlaan 88, Terneuzen @ 10:49
# Rooseveltlaan 1, Axel @ 11:46
# Molenstraat 95, Zaamslag @ 12:07
# De Poort 24, Rilland @ 13:04
# Kamerlingh Onnesweg 9, Dordrecht @ 14:22
# Aantal adressen: 6
# Afstand: 161.72 km
# Totale tijd: 382 min (6.37 uur)
# ------------------------------------------------------------
# Bus 3:
# Kamerlingh Onnesweg 9, Dordrecht @ 08:00
# Pietersdijk 60, Rotterdam @ 08:18
# Oosterhagen 17, Rotterdam @ 08:32
# Haastrechtstraat 130, Rotterdam @ 08:48
# Motorstraat 96, Rotterdam @ 09:24
# Maashaven O.Z. 103, Rotterdam @ 10:22
# Boergoensestraat 128, Rotterdam @ 10:25
# Reling 19, Barendrecht @ 10:42
# Noordbolwerk 33, Middelburg @ 12:35
# Latijnse Schoolstraat 19, Middelburg @ 13:02
# Agaat 2 -12 , Middelburg @ 13:41
# Kamerlingh Onnesweg 9, Dordrecht @ 15:59
# Aantal adressen: 10
# Afstand: 178.12 km
# Totale tijd: 479 min (7.98 uur)
# ------------------------------------------------------------

# %%
for route in routes_output4:
    if not route["vehicle_used"]:
        continue

    print(f"Bus {route['vehicle_id']}:")

    for i, (adres, tijd) in enumerate(zip(route['route_adressen'], route['route_times_min'])):
        uur = tijd // 60
        minuut = tijd % 60

        rijtijd = route["route_travel_times_min"][i]
        servicetijd = route["route_service_times_min"][i]

        print(
            f"{adres} @ {uur:02d}:{minuut:02d} "
            f"| rijtijd naar volgende locatie: {rijtijd} min "
            f"| servicetijd op locatie: {servicetijd} min"
        )

    totale_rijtijd = sum(route["route_travel_times_min"])
    totale_servicetijd = sum(route["route_service_times_min"])

    print(f"Aantal adressen: {route['aantal_adressen']}")
    print(f"Afstand: {route['afstand_km']} km")
    print(f"Rijtijd: {totale_rijtijd} min ({totale_rijtijd / 60:.2f} uur)")
    print(f"Servicetijd: {totale_servicetijd} min ({totale_servicetijd / 60:.2f} uur)")
    print(f"Totale tijd: {route['totale_tijd_min']} min ({route['totale_tijd_uur']} uur)")
    print("-" * 60)
# Out:
# Bus 0:
# Kamerlingh Onnesweg 9, Dordrecht @ 08:00 | rijtijd naar volgende locatie: 6 min | servicetijd op locatie: 0 min
# Plantageweg 3, Zwijndrecht @ 08:06 | rijtijd naar volgende locatie: 6 min | servicetijd op locatie: 34 min
# Bankastraat 158, Dordrecht @ 08:46 | rijtijd naar volgende locatie: 7 min | servicetijd op locatie: 3 min
# Touwbaan 4, Sliedrecht @ 08:56 | rijtijd naar volgende locatie: 2 min | servicetijd op locatie: 11 min
# 27           Kamerlingh Onnesweg 9, Dordrecht
# 28                       De Poort 24, Rilland
# 29                     Vliete 1, Krabbendijke
# 30                      Rooseveltlaan 1, Axel
# 31                   Molenstraat 95, Zaamslag
# 32                 Pattistpark 137, Terneuzen
# 33                     Bachlaan 88, Terneuzen
# 34                   Agaat 2 -12 , Middelburg
# 35                Noordbolwerk 33, Middelburg
# 36       Latijnse Schoolstraat 19, Middelburg
# 40           Kamerlingh Onnesweg 9, Dordrecht
# 42           Kamerlingh Onnesweg 9, Dordrecht
# 43                 Plantageweg 3, Zwijndrecht
# 44                 Bankastraat 158, Dordrecht
# 45       Albert Schweitzerplaats 1, Dordrecht
# 46                   Minnaertweg 4, Dordrecht
# 47      Groen Van Prinstererweg 38, Dordrecht

# %%
# ==============================
# MODEL 5 - HISTORISCHE SNELHEDEN
# ==============================

df_td = df05.copy()

df_td['Date'] = pd.to_datetime(df_td['Date'], errors='coerce')

# Tijdstip StartRide omzetten naar minuten vanaf middernacht
df_td['StartRide_dt'] = pd.to_datetime(df_td['StartRide'], format='%H:%M', errors='coerce')
df_td['StartRide_min'] = df_td['StartRide_dt'].dt.hour * 60 + df_td['StartRide_dt'].dt.minute

# Distance omzetten naar float
df_td['Distance_km'] = (
    df_td['Distance']
    .astype(str)
    .str.replace(',', '.', regex=False)
    .astype(float)
)

df_td['TravelTime'] = pd.to_numeric(df_td['TravelTime'], errors='coerce')

# Alleen geldige ritten meenemen
df_td = df_td.dropna(subset=['StartRide_min', 'Distance_km', 'TravelTime']).copy()

df_td = df_td[
    (df_td['TravelTime'] > 0) &
    (df_td['Distance_km'] > 0)
].copy()

# Snelheid berekenen
df_td['speed_kmh'] = df_td['Distance_km'] / (df_td['TravelTime'] / 60)

# Onrealistische snelheden eruit
df_td = df_td[
    (df_td['speed_kmh'] >= 5) &
    (df_td['speed_kmh'] <= 120)
].copy()

def get_period_from_minutes(minutes):
    if pd.isna(minutes):
        return "overig"
    if 6 * 60 <= minutes < 9 * 60:
        return "ochtendspits"
    elif 9 * 60 <= minutes < 15 * 60:
        return "dal"
    elif 15 * 60 <= minutes < 18 * 60:
        return "avondspits"
    else:
        return "overig"

df_td['time_period'] = df_td['StartRide_min'].apply(get_period_from_minutes)

speed_by_period = (
    df_td
    .groupby('time_period')['speed_kmh']
    .median()
)

default_speed = df_td['speed_kmh'].median()

period_speeds = {
    "ochtendspits": speed_by_period.get("ochtendspits", default_speed),
    "dal": speed_by_period.get("dal", default_speed),
    "avondspits": speed_by_period.get("avondspits", default_speed),
    "overig": speed_by_period.get("overig", default_speed)
}

print("Snelheden per tijdvak:")
print(period_speeds)
# Out:
# Snelheden per tijdvak:
# {'ochtendspits': np.float64(60.042857142857144), 'dal': np.float64(25.8), 'avondspits': np.float64(36.34909090909091), 'overig': np.float64(36.34909090909091)}

# %%
# ==============================
# MODEL 5 - TIME MATRICES PER TIJDVAK
# ==============================

time_matrices_model5 = {}

for period, speed in period_speeds.items():
    matrix = np.round(
        (distance_matrix / 1000) / speed * 60
    ).astype(int)

    # minimale reistijd tussen verschillende locaties = 1 minuut
    for i in range(len(matrix)):
        for j in range(len(matrix)):
            if i != j and matrix[i, j] == 0:
                matrix[i, j] = 1

    time_matrices_model5[period] = matrix

print("Matrices aangemaakt voor:")
print(time_matrices_model5.keys())
# Out:
# Matrices aangemaakt voor:
# dict_keys(['ochtendspits', 'dal', 'avondspits', 'overig'])

# %%
# ==============================
# MODEL 5 - ROUTES MET TIJDSTIPPEN UITLEZEN
# ==============================

def extract_routes_with_times(solution, manager, routing, num_vehicles, locations):
    time_dimension = routing.GetDimensionOrDie("Time")
    routes = []

    for vehicle_id in range(num_vehicles):
        index = routing.Start(vehicle_id)
        route = []

        while not routing.IsEnd(index):
            node = manager.IndexToNode(index)
            current_time = solution.Value(time_dimension.CumulVar(index))
            next_index = solution.Value(routing.NextVar(index))
            next_node = manager.IndexToNode(next_index)

            route.append({
                "vehicle_id": vehicle_id,
                "node": node,
                "address": locations.loc[node, "VisitingAddress"],
                "time_min": current_time,
                "next_node": next_node
            })

            index = next_index

        end_node = manager.IndexToNode(index)
        end_time = solution.Value(time_dimension.CumulVar(index))

        route.append({
            "vehicle_id": vehicle_id,
            "node": end_node,
            "address": locations.loc[end_node, "VisitingAddress"],
            "time_min": end_time,
            "next_node": None
        })

        routes.append(route)

    return routes

# %%
# ==============================
# MODEL 5 - MATRIX ACTUALISEREN
# ==============================

def build_time_dependent_matrix_from_solution(routes, time_matrices_model5, base_time_matrix):
    new_matrix = base_time_matrix.copy()

    for route in routes:
        for step in route:
            from_node = step["node"]
            to_node = step["next_node"]

            if to_node is None:
                continue

            departure_time = step["time_min"]
            period = get_period_from_minutes(departure_time)

            new_matrix[from_node][to_node] = time_matrices_model5[period][from_node][to_node]

    return new_matrix

# %% [markdown]
# ## Runnen

# %%
# ==============================
# MODEL 5 - ITERATIEF RUNNEN
# ==============================

MAX_ITERATIONS_MODEL5 = 8

# Startmatrix = gemiddelde van alle tijdvakmatrices
time_matrix_model5_current = np.round(
    (
        time_matrices_model5["ochtendspits"] +
        time_matrices_model5["dal"] +
        time_matrices_model5["avondspits"] +
        time_matrices_model5["overig"]
    ) / 4
).astype(int)

model5_iteration_results = []

best_solution5 = None
best_manager5 = None
best_routing5 = None
best_fs5 = None
best_ls5 = None
best_time_matrix5 = None

for iteration in range(MAX_ITERATIONS_MODEL5):
    print("=" * 80)
    print(f"MODEL 5 iteratie {iteration + 1}")
    print("=" * 80)

    df_results_iter = compare_model_4_strategies(
        time_matrix=time_matrix_model5_current,
        distance_matrix=distance_matrix,
        num_vehicles=num_vehicles,
        demands=demands,
        vehicle_capacities=vehicle_capacities,
        service_times=service_times,
        time_windows=time_windows,
        first_solution_strategies=first_solution_strategies,
        local_search_metaheuristics=local_search_metaheuristics,
        time_limit_seconds=TIME_LIMIT_SECONDS
    )

    df_results_iter["iteration"] = iteration + 1
    model5_iteration_results.append(df_results_iter)

    df_valid = df_results_iter[
        (df_results_iter["solution_found"] == True) &
        (df_results_iter["total_distance"].notna()) &
        (df_results_iter["total_distance"] > 0)
    ].copy()

    if df_valid.empty:
        print("Geen oplossing gevonden in deze iteratie.")
        break

    best_row = df_valid.sort_values(
        by=["total_distance", "runtime_sec"],
        ascending=[True, True]
    ).iloc[0]

    best_fs5 = best_row["first_solution_strategy"]
    best_ls5 = best_row["local_search_metaheuristic"]

    print("Beste combinatie deze iteratie:")
    print(best_fs5, "+", best_ls5)

    manager5, routing5 = build_model_4(
        time_matrix=time_matrix_model5_current,
        distance_matrix=distance_matrix,
        num_vehicles=num_vehicles,
        demands=demands,
        vehicle_capacities=vehicle_capacities,
        service_times=service_times,
        time_windows=time_windows,
        depot=0
    )

    search_parameters5 = pywrapcp.DefaultRoutingSearchParameters()
    search_parameters5.first_solution_strategy = getattr(
        routing_enums_pb2.FirstSolutionStrategy, best_fs5
    )
    search_parameters5.local_search_metaheuristic = getattr(
        routing_enums_pb2.LocalSearchMetaheuristic, best_ls5
    )
    search_parameters5.time_limit.seconds = TIME_LIMIT_SECONDS

    solution5 = routing5.SolveWithParameters(search_parameters5)

    if solution5 is None:
        print("Geen oplossing gevonden bij definitieve run van deze iteratie.")
        break

    routes_with_times = extract_routes_with_times(
        solution=solution5,
        manager=manager5,
        routing=routing5,
        num_vehicles=num_vehicles,
        locations=locations
    )

    new_time_matrix = build_time_dependent_matrix_from_solution(
        routes=routes_with_times,
        time_matrices_model5=time_matrices_model5,
        base_time_matrix=time_matrix_model5_current
    )

    changes = np.sum(new_time_matrix != time_matrix_model5_current)
    print("Aantal aangepaste matrixwaarden:", changes)

    best_solution5 = solution5
    best_manager5 = manager5
    best_routing5 = routing5
    best_time_matrix5 = time_matrix_model5_current.copy()

    if changes == 0:
        print("Matrix stabiel. Model 5 stopt.")
        break

    time_matrix_model5_current = new_time_matrix.copy()

df_results_model5_iterations = pd.concat(model5_iteration_results, ignore_index=True)

display(df_results_model5_iterations.head(20))
# Out:
# ================================================================================
# MODEL 5 iteratie 1
# ================================================================================
# Testen: PATH_CHEAPEST_ARC + GREEDY_DESCENT
# Testen: PATH_CHEAPEST_ARC + GUIDED_LOCAL_SEARCH
# Testen: PATH_CHEAPEST_ARC + SIMULATED_ANNEALING
# Testen: PATH_CHEAPEST_ARC + TABU_SEARCH
# Testen: PARALLEL_CHEAPEST_INSERTION + GREEDY_DESCENT
# Testen: PARALLEL_CHEAPEST_INSERTION + GUIDED_LOCAL_SEARCH
# Testen: PARALLEL_CHEAPEST_INSERTION + SIMULATED_ANNEALING
# Testen: PARALLEL_CHEAPEST_INSERTION + TABU_SEARCH
# Testen: LOCAL_CHEAPEST_INSERTION + GREEDY_DESCENT
# Testen: LOCAL_CHEAPEST_INSERTION + GUIDED_LOCAL_SEARCH
# Testen: LOCAL_CHEAPEST_INSERTION + SIMULATED_ANNEALING
# Testen: LOCAL_CHEAPEST_INSERTION + TABU_SEARCH
# Testen: GLOBAL_CHEAPEST_ARC + GREEDY_DESCENT
# Testen: GLOBAL_CHEAPEST_ARC + GUIDED_LOCAL_SEARCH
# Testen: GLOBAL_CHEAPEST_ARC + SIMULATED_ANNEALING
# Testen: GLOBAL_CHEAPEST_ARC + TABU_SEARCH
# Testen: LOCAL_CHEAPEST_ARC + GREEDY_DESCENT
# Testen: LOCAL_CHEAPEST_ARC + GUIDED_LOCAL_SEARCH
# Testen: LOCAL_CHEAPEST_ARC + SIMULATED_ANNEALING
# Testen: LOCAL_CHEAPEST_ARC + TABU_SEARCH
# Testen: SAVINGS + GREEDY_DESCENT
# Testen: SAVINGS + GUIDED_LOCAL_SEARCH
# Testen: SAVINGS + SIMULATED_ANNEALING
# Testen: SAVINGS + TABU_SEARCH
# Beste combinatie deze iteratie:
# PATH_CHEAPEST_ARC + GREEDY_DESCENT
# Aantal aangepaste matrixwaarden: 26
# ================================================================================
# MODEL 5 iteratie 2
# ================================================================================
# Testen: PATH_CHEAPEST_ARC + GREEDY_DESCENT
# Testen: PATH_CHEAPEST_ARC + GUIDED_LOCAL_SEARCH
# Testen: PATH_CHEAPEST_ARC + SIMULATED_ANNEALING
# Testen: PATH_CHEAPEST_ARC + TABU_SEARCH
# Testen: PARALLEL_CHEAPEST_INSERTION + GREEDY_DESCENT
# Testen: PARALLEL_CHEAPEST_INSERTION + GUIDED_LOCAL_SEARCH
# Testen: PARALLEL_CHEAPEST_INSERTION + SIMULATED_ANNEALING
# Testen: PARALLEL_CHEAPEST_INSERTION + TABU_SEARCH
# Testen: LOCAL_CHEAPEST_INSERTION + GREEDY_DESCENT
# Testen: LOCAL_CHEAPEST_INSERTION + GUIDED_LOCAL_SEARCH
# Testen: LOCAL_CHEAPEST_INSERTION + SIMULATED_ANNEALING
# Testen: LOCAL_CHEAPEST_INSERTION + TABU_SEARCH
# Testen: GLOBAL_CHEAPEST_ARC + GREEDY_DESCENT
# Testen: GLOBAL_CHEAPEST_ARC + GUIDED_LOCAL_SEARCH
# Testen: GLOBAL_CHEAPEST_ARC + SIMULATED_ANNEALING
# Testen: GLOBAL_CHEAPEST_ARC + TABU_SEARCH
# Testen: LOCAL_CHEAPEST_ARC + GREEDY_DESCENT
# Testen: LOCAL_CHEAPEST_ARC + GUIDED_LOCAL_SEARCH
# Testen: LOCAL_CHEAPEST_ARC + SIMULATED_ANNEALING
# Testen: LOCAL_CHEAPEST_ARC + TABU_SEARCH
# Testen: SAVINGS + GREEDY_DESCENT
# Testen: SAVINGS + GUIDED_LOCAL_SEARCH
# Testen: SAVINGS + SIMULATED_ANNEALING
# Testen: SAVINGS + TABU_SEARCH
# Beste combinatie deze iteratie:
# PATH_CHEAPEST_ARC + GUIDED_LOCAL_SEARCH
# Aantal aangepaste matrixwaarden: 19
# ================================================================================
# MODEL 5 iteratie 3
# ================================================================================
# Testen: PATH_CHEAPEST_ARC + GREEDY_DESCENT
# Testen: PATH_CHEAPEST_ARC + GUIDED_LOCAL_SEARCH
# Testen: PATH_CHEAPEST_ARC + SIMULATED_ANNEALING
# Testen: PATH_CHEAPEST_ARC + TABU_SEARCH
# Testen: PARALLEL_CHEAPEST_INSERTION + GREEDY_DESCENT
# Testen: PARALLEL_CHEAPEST_INSERTION + GUIDED_LOCAL_SEARCH
# Testen: PARALLEL_CHEAPEST_INSERTION + SIMULATED_ANNEALING
# Testen: PARALLEL_CHEAPEST_INSERTION + TABU_SEARCH
# Testen: LOCAL_CHEAPEST_INSERTION + GREEDY_DESCENT
# Testen: LOCAL_CHEAPEST_INSERTION + GUIDED_LOCAL_SEARCH
# Testen: LOCAL_CHEAPEST_INSERTION + SIMULATED_ANNEALING
# Testen: LOCAL_CHEAPEST_INSERTION + TABU_SEARCH
# Testen: GLOBAL_CHEAPEST_ARC + GREEDY_DESCENT
# Testen: GLOBAL_CHEAPEST_ARC + GUIDED_LOCAL_SEARCH
# Testen: GLOBAL_CHEAPEST_ARC + SIMULATED_ANNEALING
# Testen: GLOBAL_CHEAPEST_ARC + TABU_SEARCH
# Testen: LOCAL_CHEAPEST_ARC + GREEDY_DESCENT
# Testen: LOCAL_CHEAPEST_ARC + GUIDED_LOCAL_SEARCH
# Testen: LOCAL_CHEAPEST_ARC + SIMULATED_ANNEALING
# Testen: LOCAL_CHEAPEST_ARC + TABU_SEARCH
# Testen: SAVINGS + GREEDY_DESCENT
# Testen: SAVINGS + GUIDED_LOCAL_SEARCH
# Testen: SAVINGS + SIMULATED_ANNEALING
# Testen: SAVINGS + TABU_SEARCH
# Beste combinatie deze iteratie:
# PARALLEL_CHEAPEST_INSERTION + GREEDY_DESCENT
# Aantal aangepaste matrixwaarden: 12
# ================================================================================
# MODEL 5 iteratie 4
# ================================================================================
# Testen: PATH_CHEAPEST_ARC + GREEDY_DESCENT
# Testen: PATH_CHEAPEST_ARC + GUIDED_LOCAL_SEARCH
# Testen: PATH_CHEAPEST_ARC + SIMULATED_ANNEALING
# Testen: PATH_CHEAPEST_ARC + TABU_SEARCH
# Testen: PARALLEL_CHEAPEST_INSERTION + GREEDY_DESCENT
# Testen: PARALLEL_CHEAPEST_INSERTION + GUIDED_LOCAL_SEARCH
# Testen: PARALLEL_CHEAPEST_INSERTION + SIMULATED_ANNEALING
# Testen: PARALLEL_CHEAPEST_INSERTION + TABU_SEARCH
# Testen: LOCAL_CHEAPEST_INSERTION + GREEDY_DESCENT
# Testen: LOCAL_CHEAPEST_INSERTION + GUIDED_LOCAL_SEARCH
# Testen: LOCAL_CHEAPEST_INSERTION + SIMULATED_ANNEALING
# Testen: LOCAL_CHEAPEST_INSERTION + TABU_SEARCH
# Testen: GLOBAL_CHEAPEST_ARC + GREEDY_DESCENT
# Testen: GLOBAL_CHEAPEST_ARC + GUIDED_LOCAL_SEARCH
# Testen: GLOBAL_CHEAPEST_ARC + SIMULATED_ANNEALING
# Testen: GLOBAL_CHEAPEST_ARC + TABU_SEARCH
# Testen: LOCAL_CHEAPEST_ARC + GREEDY_DESCENT
# Testen: LOCAL_CHEAPEST_ARC + GUIDED_LOCAL_SEARCH
# Testen: LOCAL_CHEAPEST_ARC + SIMULATED_ANNEALING
# Testen: LOCAL_CHEAPEST_ARC + TABU_SEARCH
# Testen: SAVINGS + GREEDY_DESCENT
# Testen: SAVINGS + GUIDED_LOCAL_SEARCH
# Testen: SAVINGS + SIMULATED_ANNEALING
# Testen: SAVINGS + TABU_SEARCH
# Beste combinatie deze iteratie:
# PARALLEL_CHEAPEST_INSERTION + TABU_SEARCH
# Aantal aangepaste matrixwaarden: 7
# ================================================================================
# MODEL 5 iteratie 5
# ================================================================================
# Testen: PATH_CHEAPEST_ARC + GREEDY_DESCENT
# Testen: PATH_CHEAPEST_ARC + GUIDED_LOCAL_SEARCH
# Testen: PATH_CHEAPEST_ARC + SIMULATED_ANNEALING
# Testen: PATH_CHEAPEST_ARC + TABU_SEARCH
# Testen: PARALLEL_CHEAPEST_INSERTION + GREEDY_DESCENT
# Testen: PARALLEL_CHEAPEST_INSERTION + GUIDED_LOCAL_SEARCH
# Testen: PARALLEL_CHEAPEST_INSERTION + SIMULATED_ANNEALING
# Testen: PARALLEL_CHEAPEST_INSERTION + TABU_SEARCH
# Testen: LOCAL_CHEAPEST_INSERTION + GREEDY_DESCENT
# Testen: LOCAL_CHEAPEST_INSERTION + GUIDED_LOCAL_SEARCH
# Testen: LOCAL_CHEAPEST_INSERTION + SIMULATED_ANNEALING
# Testen: LOCAL_CHEAPEST_INSERTION + TABU_SEARCH
# Testen: GLOBAL_CHEAPEST_ARC + GREEDY_DESCENT
# Testen: GLOBAL_CHEAPEST_ARC + GUIDED_LOCAL_SEARCH
# Testen: GLOBAL_CHEAPEST_ARC + SIMULATED_ANNEALING
# Testen: GLOBAL_CHEAPEST_ARC + TABU_SEARCH
# Testen: LOCAL_CHEAPEST_ARC + GREEDY_DESCENT
# Testen: LOCAL_CHEAPEST_ARC + GUIDED_LOCAL_SEARCH
# Testen: LOCAL_CHEAPEST_ARC + SIMULATED_ANNEALING
# Testen: LOCAL_CHEAPEST_ARC + TABU_SEARCH
# Testen: SAVINGS + GREEDY_DESCENT
# Testen: SAVINGS + GUIDED_LOCAL_SEARCH
# Testen: SAVINGS + SIMULATED_ANNEALING
# Testen: SAVINGS + TABU_SEARCH
# Beste combinatie deze iteratie:
# SAVINGS + TABU_SEARCH
# Aantal aangepaste matrixwaarden: 8
# ================================================================================
# MODEL 5 iteratie 6
# ================================================================================
# Testen: PATH_CHEAPEST_ARC + GREEDY_DESCENT
# Testen: PATH_CHEAPEST_ARC + GUIDED_LOCAL_SEARCH
# Testen: PATH_CHEAPEST_ARC + SIMULATED_ANNEALING
# Testen: PATH_CHEAPEST_ARC + TABU_SEARCH
# Testen: PARALLEL_CHEAPEST_INSERTION + GREEDY_DESCENT
# Testen: PARALLEL_CHEAPEST_INSERTION + GUIDED_LOCAL_SEARCH
# Testen: PARALLEL_CHEAPEST_INSERTION + SIMULATED_ANNEALING
# Testen: PARALLEL_CHEAPEST_INSERTION + TABU_SEARCH
# Testen: LOCAL_CHEAPEST_INSERTION + GREEDY_DESCENT
# Testen: LOCAL_CHEAPEST_INSERTION + GUIDED_LOCAL_SEARCH
# Testen: LOCAL_CHEAPEST_INSERTION + SIMULATED_ANNEALING
# Testen: LOCAL_CHEAPEST_INSERTION + TABU_SEARCH
# Testen: GLOBAL_CHEAPEST_ARC + GREEDY_DESCENT
# Testen: GLOBAL_CHEAPEST_ARC + GUIDED_LOCAL_SEARCH
# Testen: GLOBAL_CHEAPEST_ARC + SIMULATED_ANNEALING
# Testen: GLOBAL_CHEAPEST_ARC + TABU_SEARCH
# Testen: LOCAL_CHEAPEST_ARC + GREEDY_DESCENT
# Testen: LOCAL_CHEAPEST_ARC + GUIDED_LOCAL_SEARCH
# Testen: LOCAL_CHEAPEST_ARC + SIMULATED_ANNEALING
# Testen: LOCAL_CHEAPEST_ARC + TABU_SEARCH
# Testen: SAVINGS + GREEDY_DESCENT
# Testen: SAVINGS + GUIDED_LOCAL_SEARCH
# Testen: SAVINGS + SIMULATED_ANNEALING
# Testen: SAVINGS + TABU_SEARCH
# Beste combinatie deze iteratie:
# PARALLEL_CHEAPEST_INSERTION + GREEDY_DESCENT
# Aantal aangepaste matrixwaarden: 5
# ================================================================================
# MODEL 5 iteratie 7
# ================================================================================
# Testen: PATH_CHEAPEST_ARC + GREEDY_DESCENT
# Testen: PATH_CHEAPEST_ARC + GUIDED_LOCAL_SEARCH
# Testen: PATH_CHEAPEST_ARC + SIMULATED_ANNEALING
# Testen: PATH_CHEAPEST_ARC + TABU_SEARCH
# Testen: PARALLEL_CHEAPEST_INSERTION + GREEDY_DESCENT
# Testen: PARALLEL_CHEAPEST_INSERTION + GUIDED_LOCAL_SEARCH
# Testen: PARALLEL_CHEAPEST_INSERTION + SIMULATED_ANNEALING
# Testen: PARALLEL_CHEAPEST_INSERTION + TABU_SEARCH
# Testen: LOCAL_CHEAPEST_INSERTION + GREEDY_DESCENT
# Testen: LOCAL_CHEAPEST_INSERTION + GUIDED_LOCAL_SEARCH
# Testen: LOCAL_CHEAPEST_INSERTION + SIMULATED_ANNEALING
# Testen: LOCAL_CHEAPEST_INSERTION + TABU_SEARCH
# Testen: GLOBAL_CHEAPEST_ARC + GREEDY_DESCENT
# Testen: GLOBAL_CHEAPEST_ARC + GUIDED_LOCAL_SEARCH
# Testen: GLOBAL_CHEAPEST_ARC + SIMULATED_ANNEALING
# Testen: GLOBAL_CHEAPEST_ARC + TABU_SEARCH
# Testen: LOCAL_CHEAPEST_ARC + GREEDY_DESCENT
# Testen: LOCAL_CHEAPEST_ARC + GUIDED_LOCAL_SEARCH
# Testen: LOCAL_CHEAPEST_ARC + SIMULATED_ANNEALING
# Testen: LOCAL_CHEAPEST_ARC + TABU_SEARCH
# Testen: SAVINGS + GREEDY_DESCENT
# Testen: SAVINGS + GUIDED_LOCAL_SEARCH
# Testen: SAVINGS + SIMULATED_ANNEALING
# Testen: SAVINGS + TABU_SEARCH
# Beste combinatie deze iteratie:
# GLOBAL_CHEAPEST_ARC + TABU_SEARCH
# Aantal aangepaste matrixwaarden: 1
# ================================================================================
# MODEL 5 iteratie 8
# ================================================================================
# Testen: PATH_CHEAPEST_ARC + GREEDY_DESCENT
# Testen: PATH_CHEAPEST_ARC + GUIDED_LOCAL_SEARCH
# Testen: PATH_CHEAPEST_ARC + SIMULATED_ANNEALING
# Testen: PATH_CHEAPEST_ARC + TABU_SEARCH
# Testen: PARALLEL_CHEAPEST_INSERTION + GREEDY_DESCENT
# Testen: PARALLEL_CHEAPEST_INSERTION + GUIDED_LOCAL_SEARCH
# Testen: PARALLEL_CHEAPEST_INSERTION + SIMULATED_ANNEALING
# Testen: PARALLEL_CHEAPEST_INSERTION + TABU_SEARCH
# Testen: LOCAL_CHEAPEST_INSERTION + GREEDY_DESCENT
# Testen: LOCAL_CHEAPEST_INSERTION + GUIDED_LOCAL_SEARCH
# Testen: LOCAL_CHEAPEST_INSERTION + SIMULATED_ANNEALING
# Testen: LOCAL_CHEAPEST_INSERTION + TABU_SEARCH
# Testen: GLOBAL_CHEAPEST_ARC + GREEDY_DESCENT
# Testen: GLOBAL_CHEAPEST_ARC + GUIDED_LOCAL_SEARCH
# Testen: GLOBAL_CHEAPEST_ARC + SIMULATED_ANNEALING
# Testen: GLOBAL_CHEAPEST_ARC + TABU_SEARCH
# Testen: LOCAL_CHEAPEST_ARC + GREEDY_DESCENT
# Testen: LOCAL_CHEAPEST_ARC + GUIDED_LOCAL_SEARCH
# Testen: LOCAL_CHEAPEST_ARC + SIMULATED_ANNEALING
# Testen: LOCAL_CHEAPEST_ARC + TABU_SEARCH
# Testen: SAVINGS + GREEDY_DESCENT
# Testen: SAVINGS + GUIDED_LOCAL_SEARCH
# Testen: SAVINGS + SIMULATED_ANNEALING
# Testen: SAVINGS + TABU_SEARCH
# Beste combinatie deze iteratie:
# GLOBAL_CHEAPEST_ARC + TABU_SEARCH
# Aantal aangepaste matrixwaarden: 1
#         first_solution_strategy local_search_metaheuristic  solution_found  \
# 0             PATH_CHEAPEST_ARC             GREEDY_DESCENT            True
# 1             PATH_CHEAPEST_ARC                TABU_SEARCH            True
# 2            LOCAL_CHEAPEST_ARC                TABU_SEARCH            True
# 3             PATH_CHEAPEST_ARC        GUIDED_LOCAL_SEARCH            True
# 4             PATH_CHEAPEST_ARC        SIMULATED_ANNEALING            True
# 5   PARALLEL_CHEAPEST_INSERTION        GUIDED_LOCAL_SEARCH            True
# 6   PARALLEL_CHEAPEST_INSERTION                TABU_SEARCH            True
# 7      LOCAL_CHEAPEST_INSERTION        GUIDED_LOCAL_SEARCH            True
# 8           GLOBAL_CHEAPEST_ARC        GUIDED_LOCAL_SEARCH            True
# 9            LOCAL_CHEAPEST_ARC        GUIDED_LOCAL_SEARCH            True
# 10                      SAVINGS        GUIDED_LOCAL_SEARCH            True
# 11                      SAVINGS                TABU_SEARCH            True
# 12     LOCAL_CHEAPEST_INSERTION             GREEDY_DESCENT            True
# 13     LOCAL_CHEAPEST_INSERTION                TABU_SEARCH            True
# 14          GLOBAL_CHEAPEST_ARC                TABU_SEARCH            True
# 15     LOCAL_CHEAPEST_INSERTION        SIMULATED_ANNEALING            True
# 16          GLOBAL_CHEAPEST_ARC             GREEDY_DESCENT            True
# 17  PARALLEL_CHEAPEST_INSERTION             GREEDY_DESCENT            True
# 18  PARALLEL_CHEAPEST_INSERTION        SIMULATED_ANNEALING            True
# 19          GLOBAL_CHEAPEST_ARC        SIMULATED_ANNEALING            True
#
#     total_distance  used_vehicles  max_route_time_min  runtime_sec  iteration
# 0           403158              3                 921         0.05          1
# 1           403158              3                 921         7.67          1
# 2           403158              3                 921         8.45          1
# 3           403158              3                 921        10.00          1
# 4           403158              3                 921        10.00          1
# 5           403158              3                 921        10.00          1
# 6           403158              3                 921        10.00          1
# 7           403158              3                 921        10.00          1
# 8           403158              3                 921        10.00          1
# 9           403158              3                 921        10.00          1
# 10          403158              3                 921        10.00          1
# 11          403158              3                 921        10.00          1
# 12          404048              3                 942         0.03          1
# 13          404048              3                 942         0.64          1
# 14          404048              3                 942         6.32          1
# 15          404048              3                 942        10.00          1
# 16          404676              4                 886         0.03          1
# 17          404676              4                 886         0.04          1
# 18          404676              4                 886        10.00          1
# 19          404676              4                 886        10.00          1

# %%
# ==============================
# MODEL 5 - RESULTATEN
# ==============================

if best_solution5:
    totaal_afstand5, routes_output5 = extract_model_4_routes(
        solution=best_solution5,
        manager=best_manager5,
        routing=best_routing5,
        num_vehicles=num_vehicles,
        locations=locations,
        demands=demands,
        time_matrix=best_time_matrix5
    )

    print(f"\nMODEL 5: Totale afstand: {round(totaal_afstand5 / 1000, 2)} km")
    print(f"Beste laatste combinatie: {best_fs5} + {best_ls5}\n")

    for route in routes_output5:
        if not route["vehicle_used"]:
            continue

        print(f"Bus {route['vehicle_id']}:")

        for i, (adres, tijd) in enumerate(
            zip(route["route_adressen"], route["route_times_min"])
        ):
            uur = tijd // 60
            minuut = tijd % 60
            periode = get_period_from_minutes(tijd)

            rijtijd = route["route_travel_times_min"][i]
            servicetijd = route["route_service_times_min"][i]

            print(
                f"{adres} @ {uur:02d}:{minuut:02d} ({periode}) "
                f"| rijtijd naar volgende locatie: {rijtijd} min "
                f"| servicetijd op locatie: {servicetijd} min"
            )

        totale_rijtijd = sum(route["route_travel_times_min"])
        totale_servicetijd = sum(route["route_service_times_min"])

        print(f"Aantal adressen: {route['aantal_adressen']}")
        print(f"Afstand: {route['afstand_km']} km")
        print(f"Rijtijd: {totale_rijtijd} min ({totale_rijtijd / 60:.2f} uur)")
        print(f"Servicetijd: {totale_servicetijd} min ({totale_servicetijd / 60:.2f} uur)")
        print(f"Totale tijd: {route['totale_tijd_min']} min ({route['totale_tijd_uur']} uur)")
        print("-" * 60)

else:
    print("MODEL 5: Geen oplossing gevonden.")
# Out:
# MODEL 5: Totale afstand: 394.25 km
# Beste laatste combinatie: GLOBAL_CHEAPEST_ARC + TABU_SEARCH
#
# Bus 1:
# Kamerlingh Onnesweg 9, Dordrecht @ 08:00 (ochtendspits) | rijtijd naar volgende locatie: 77 min | servicetijd op locatie: 0 min
# Agaat 2 -12 , Middelburg @ 09:17 (dal) | rijtijd naar volgende locatie: 3 min | servicetijd op locatie: 22 min
# Noordbolwerk 33, Middelburg @ 09:42 (dal) | rijtijd naar volgende locatie: 1 min | servicetijd op locatie: 26 min
# Latijnse Schoolstraat 19, Middelburg @ 10:09 (dal) | rijtijd naar volgende locatie: 123 min | servicetijd op locatie: 38 min
# Motorstraat 96, Rotterdam @ 12:50 (dal) | rijtijd naar volgende locatie: 4 min | servicetijd op locatie: 56 min
# Boergoensestraat 128, Rotterdam @ 13:50 (dal) | rijtijd naar volgende locatie: 5 min | servicetijd op locatie: 9 min
# Maashaven O.Z. 103, Rotterdam @ 14:04 (dal) | rijtijd naar volgende locatie: 11 min | servicetijd op locatie: 0 min
# Oosterhagen 17, Rotterdam @ 14:15 (dal) | rijtijd naar volgende locatie: 3 min | servicetijd op locatie: 13 min
# Pietersdijk 60, Rotterdam @ 14:31 (dal) | rijtijd naar volgende locatie: 3 min | servicetijd op locatie: 12 min
# Haastrechtstraat 130, Rotterdam @ 14:46 (dal) | rijtijd naar volgende locatie: 10 min | servicetijd op locatie: 32 min
# Reling 19, Barendrecht @ 15:28 (avondspits) | rijtijd naar volgende locatie: 20 min | servicetijd op locatie: 5 min
# Kamerlingh Onnesweg 9, Dordrecht @ 15:53 (avondspits) | rijtijd naar volgende locatie: 0 min | servicetijd op locatie: 0 min
# Aantal adressen: 10
# Afstand: 181.38 km
# Rijtijd: 260 min (4.33 uur)
# Servicetijd: 213 min (3.55 uur)
# Totale tijd: 473 min (7.88 uur)
# ------------------------------------------------------------
# Bus 2:
