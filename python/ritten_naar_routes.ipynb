# %%
import pandas as pd

# %%
df = pd.read_csv(
    'Ritten per voertuig 01-01-2025 - 31-12-2025.Csv',
    sep=';',
    encoding='utf-16',
    skiprows=1  # <-- dit is de key!
)

# %%
df
# Out:
#              Date StartTime StopTime                                   From  \
# 0      02-01-2025     06:48    07:17         Vlaardingen, Produktiestraat 2
# 1      02-01-2025     10:27    10:39         Vlaardingen, Produktiestraat 2
# 2      02-01-2025     10:43    11:36         Vlaardingen, Produktiestraat 2
# 3      02-01-2025     12:17    12:58         Vlaardingen, Produktiestraat 2
# 4      02-01-2025     14:51    15:06         Vlaardingen, Produktiestraat 2
# ...           ...       ...      ...                                    ...
# 59157  31-12-2025     10:18    10:38        Rotterdam, Van Beethovenlaan 56
# 59158  31-12-2025     10:57    11:28  Capelle Aan Den Ijssel, Dotterlei 143
# 59159  31-12-2025     11:46    11:54  Dordrecht, Groen Van Prinstererweg 38
# 59160  31-12-2025     12:02    12:10               Dordrecht, Minnaertweg 4
# 59161  31-12-2025     12:21    12:23       Dordrecht, Kamerlingh Onnesweg 9
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 59162 entries, 0 to 59161
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          59162 non-null  str
#  1   StartTime     59162 non-null  str
#  2   StopTime      59162 non-null  str
#  3   From          59162 non-null  str
#  4   To            59162 non-null  str
#  5   Distance      59162 non-null  str
#  6   Time          59162 non-null  str
#  7   DriverName    55234 non-null  str
#  8   SerialNumber  59162 non-null  str
# dtypes: str(9)
# memory usage: 4.1 MB
